# %%
import math
import numpy as np
import matplotlib.pyplot as plt
import os
import sys

sys.path.append('../../modules')

# Imports the python definition of f(x) for problem 1.

from problem_function import f

# %%
from metaheuristics import taboo_search
# Out:
# Requirement already satisfied: numpy in c:\users\danzi\appdata\local\programs\python\python35\lib\site-packages (1.15.3)

# %%
# Graph the results of one full GA run

def plot_taboo_search_metaheuristic(f, xrange, results, print_data=False):
    xs = np.linspace(xrange[0], xrange[1], 2*(xrange[1]-xrange[0]))
    ys = np.array([f(i) for i in xs])
    
    midpoint = (int(abs(xs[-1]-xs[0])/2), int(abs(ys[-1]-ys[0])/2))
    
    data = results[0]
    data_length = len(data)
    solution = results[1]
    
    # MatPlotLib
    
    # Plot the problem line
    plt.title("Problem line (only)")
    plt.plot(xs, ys, '-g', label="f(x)")
    plt.legend(framealpha=0.4)
    plt.xlabel("x")
    plt.ylabel("f(x)")
    plt.show()
    
    xplots = []
    yplots = []
    
    # Get plotting data
    if (print_data == True):
        print("Plot data (2DP)\n_____________________________________\nX")
    for i in range(data_length):
        val = data[i]
        xplots.append(val)
        yplots.append(f(val))
        if (print_data == True):
            print(round(val, 2))
    
    # Plot best results against problem line
    plt.title("Results against problem line")
    line = plt.plot(xs, ys, '-g', label="f(x)")
    plt.plot(xplots, yplots, "o", color="b", label="Solution")
    
    # Annotate first and last plots
    plt.annotate(s="First s", xy=(xplots[0], yplots[0]), xytext=(midpoint[0], midpoint[1]+170), arrowprops=dict(arrowstyle='->'))
    plt.annotate(s="Last s", xy=(xplots[-1], yplots[-1]), xytext=(midpoint[0], midpoint[1]+30), arrowprops=dict(arrowstyle='->'))
    
    plt.legend(framealpha=0.4)
    plt.xlabel("x")
    plt.ylabel("f(x)")
    plt.show()

# %%
s0 = 120
def stop_function(i, s, viable_neighbours, max_i):
    return (i != 0 and (max_i < i or (viable_neighbours == 0)))
taboo_memory = 5
def get_neighbourhood(s0, step_size):
    return [round(s0 - step_size, 2), round(s0 + step_size, 2)]
max_i = 300
step_size = 0.1

results = taboo_search(f, s0, stop_function, taboo_memory, get_neighbourhood, True, stop_args={"max_i": max_i}, neighbourhood_args={"step_size": step_size})
# Out:
# Iteration: 1,	Current solution: 119.9,	Taboo list: [120, 119.9]
# Iteration: 2,	Current solution: 119.8,	Taboo list: [120, 119.9, 119.8]
# Iteration: 3,	Current solution: 119.7,	Taboo list: [120, 119.9, 119.8, 119.7]
# Iteration: 4,	Current solution: 119.6,	Taboo list: [120, 119.9, 119.8, 119.7, 119.6]
# Iteration: 5,	Current solution: 119.5,	Taboo list: [119.9, 119.8, 119.7, 119.6, 119.5]
# Iteration: 6,	Current solution: 119.4,	Taboo list: [119.8, 119.7, 119.6, 119.5, 119.4]
# Iteration: 7,	Current solution: 119.3,	Taboo list: [119.7, 119.6, 119.5, 119.4, 119.3]
# Iteration: 8,	Current solution: 119.2,	Taboo list: [119.6, 119.5, 119.4, 119.3, 119.2]
# Iteration: 9,	Current solution: 119.1,	Taboo list: [119.5, 119.4, 119.3, 119.2, 119.1]
# Iteration: 10,	Current solution: 119.0,	Taboo list: [119.4, 119.3, 119.2, 119.1, 119.0]
# Iteration: 11,	Current solution: 118.9,	Taboo list: [119.3, 119.2, 119.1, 119.0, 118.9]
# Iteration: 12,	Current solution: 118.8,	Taboo list: [119.2, 119.1, 119.0, 118.9, 118.8]
# Iteration: 13,	Current solution: 118.7,	Taboo list: [119.1, 119.0, 118.9, 118.8, 118.7]
# Iteration: 14,	Current solution: 118.6,	Taboo list: [119.0, 118.9, 118.8, 118.7, 118.6]
# Iteration: 15,	Current solution: 118.5,	Taboo list: [118.9, 118.8, 118.7, 118.6, 118.5]
# Iteration: 16,	Current solution: 118.4,	Taboo list: [118.8, 118.7, 118.6, 118.5, 118.4]
# Iteration: 17,	Current solution: 118.3,	Taboo list: [118.7, 118.6, 118.5, 118.4, 118.3]
# Iteration: 18,	Current solution: 118.2,	Taboo list: [118.6, 118.5, 118.4, 118.3, 118.2]
# Iteration: 19,	Current solution: 118.1,	Taboo list: [118.5, 118.4, 118.3, 118.2, 118.1]
# Iteration: 20,	Current solution: 118.0,	Taboo list: [118.4, 118.3, 118.2, 118.1, 118.0]
# Iteration: 21,	Current solution: 117.9,	Taboo list: [118.3, 118.2, 118.1, 118.0, 117.9]
# Iteration: 22,	Current solution: 117.8,	Taboo list: [118.2, 118.1, 118.0, 117.9, 117.8]
# Iteration: 23,	Current solution: 117.7,	Taboo list: [118.1, 118.0, 117.9, 117.8, 117.7]
# Iteration: 24,	Current solution: 117.6,	Taboo list: [118.0, 117.9, 117.8, 117.7, 117.6]
# Iteration: 25,	Current solution: 117.5,	Taboo list: [117.9, 117.8, 117.7, 117.6, 117.5]
# Iteration: 26,	Current solution: 117.4,	Taboo list: [117.8, 117.7, 117.6, 117.5, 117.4]
# Iteration: 27,	Current solution: 117.3,	Taboo list: [117.7, 117.6, 117.5, 117.4, 117.3]
# Iteration: 28,	Current solution: 117.2,	Taboo list: [117.6, 117.5, 117.4, 117.3, 117.2]
# Iteration: 29,	Current solution: 117.1,	Taboo list: [117.5, 117.4, 117.3, 117.2, 117.1]
# Iteration: 30,	Current solution: 117.0,	Taboo list: [117.4, 117.3, 117.2, 117.1, 117.0]
# Iteration: 31,	Current solution: 116.9,	Taboo list: [117.3, 117.2, 117.1, 117.0, 116.9]
# Iteration: 32,	Current solution: 116.8,	Taboo list: [117.2, 117.1, 117.0, 116.9, 116.8]
# Iteration: 33,	Current solution: 116.7,	Taboo list: [117.1, 117.0, 116.9, 116.8, 116.7]
# Iteration: 34,	Current solution: 116.6,	Taboo list: [117.0, 116.9, 116.8, 116.7, 116.6]
# Iteration: 35,	Current solution: 116.5,	Taboo list: [116.9, 116.8, 116.7, 116.6, 116.5]
# Iteration: 36,	Current solution: 116.4,	Taboo list: [116.8, 116.7, 116.6, 116.5, 116.4]
# Iteration: 37,	Current solution: 116.3,	Taboo list: [116.7, 116.6, 116.5, 116.4, 116.3]
# Iteration: 38,	Current solution: 116.2,	Taboo list: [116.6, 116.5, 116.4, 116.3, 116.2]
# Iteration: 39,	Current solution: 116.1,	Taboo list: [116.5, 116.4, 116.3, 116.2, 116.1]
# Iteration: 40,	Current solution: 116.0,	Taboo list: [116.4, 116.3, 116.2, 116.1, 116.0]
# Iteration: 41,	Current solution: 115.9,	Taboo list: [116.3, 116.2, 116.1, 116.0, 115.9]
# Iteration: 42,	Current solution: 115.8,	Taboo list: [116.2, 116.1, 116.0, 115.9, 115.8]
# Iteration: 43,	Current solution: 115.7,	Taboo list: [116.1, 116.0, 115.9, 115.8, 115.7]
# Iteration: 44,	Current solution: 115.6,	Taboo list: [116.0, 115.9, 115.8, 115.7, 115.6]
# Iteration: 45,	Current solution: 115.5,	Taboo list: [115.9, 115.8, 115.7, 115.6, 115.5]
# Iteration: 46,	Current solution: 115.4,	Taboo list: [115.8, 115.7, 115.6, 115.5, 115.4]
# Iteration: 47,	Current solution: 115.3,	Taboo list: [115.7, 115.6, 115.5, 115.4, 115.3]
# Iteration: 48,	Current solution: 115.2,	Taboo list: [115.6, 115.5, 115.4, 115.3, 115.2]
# Iteration: 49,	Current solution: 115.1,	Taboo list: [115.5, 115.4, 115.3, 115.2, 115.1]
# Iteration: 50,	Current solution: 115.0,	Taboo list: [115.4, 115.3, 115.2, 115.1, 115.0]
# Iteration: 51,	Current solution: 114.9,	Taboo list: [115.3, 115.2, 115.1, 115.0, 114.9]
# Iteration: 52,	Current solution: 114.8,	Taboo list: [115.2, 115.1, 115.0, 114.9, 114.8]
# Iteration: 53,	Current solution: 114.7,	Taboo list: [115.1, 115.0, 114.9, 114.8, 114.7]
# Iteration: 54,	Current solution: 114.6,	Taboo list: [115.0, 114.9, 114.8, 114.7, 114.6]
# Iteration: 55,	Current solution: 114.5,	Taboo list: [114.9, 114.8, 114.7, 114.6, 114.5]
# Iteration: 56,	Current solution: 114.4,	Taboo list: [114.8, 114.7, 114.6, 114.5, 114.4]
# Iteration: 57,	Current solution: 114.3,	Taboo list: [114.7, 114.6, 114.5, 114.4, 114.3]
# Iteration: 58,	Current solution: 114.2,	Taboo list: [114.6, 114.5, 114.4, 114.3, 114.2]
# Iteration: 59,	Current solution: 114.1,	Taboo list: [114.5, 114.4, 114.3, 114.2, 114.1]
# Iteration: 60,	Current solution: 114.0,	Taboo list: [114.4, 114.3, 114.2, 114.1, 114.0]
# Iteration: 61,	Current solution: 113.9,	Taboo list: [114.3, 114.2, 114.1, 114.0, 113.9]
# Iteration: 62,	Current solution: 113.8,	Taboo list: [114.2, 114.1, 114.0, 113.9, 113.8]
# Iteration: 63,	Current solution: 113.7,	Taboo list: [114.1, 114.0, 113.9, 113.8, 113.7]
# Iteration: 64,	Current solution: 113.6,	Taboo list: [114.0, 113.9, 113.8, 113.7, 113.6]
# Iteration: 65,	Current solution: 113.5,	Taboo list: [113.9, 113.8, 113.7, 113.6, 113.5]
# Iteration: 66,	Current solution: 113.4,	Taboo list: [113.8, 113.7, 113.6, 113.5, 113.4]
# Iteration: 67,	Current solution: 113.3,	Taboo list: [113.7, 113.6, 113.5, 113.4, 113.3]
# Iteration: 68,	Current solution: 113.2,	Taboo list: [113.6, 113.5, 113.4, 113.3, 113.2]
# Iteration: 69,	Current solution: 113.1,	Taboo list: [113.5, 113.4, 113.3, 113.2, 113.1]
# Iteration: 70,	Current solution: 113.0,	Taboo list: [113.4, 113.3, 113.2, 113.1, 113.0]
# Iteration: 71,	Current solution: 112.9,	Taboo list: [113.3, 113.2, 113.1, 113.0, 112.9]
# Iteration: 72,	Current solution: 112.8,	Taboo list: [113.2, 113.1, 113.0, 112.9, 112.8]
# Iteration: 73,	Current solution: 112.7,	Taboo list: [113.1, 113.0, 112.9, 112.8, 112.7]
# Iteration: 74,	Current solution: 112.6,	Taboo list: [113.0, 112.9, 112.8, 112.7, 112.6]
# Iteration: 75,	Current solution: 112.5,	Taboo list: [112.9, 112.8, 112.7, 112.6, 112.5]
# Iteration: 76,	Current solution: 112.4,	Taboo list: [112.8, 112.7, 112.6, 112.5, 112.4]
# Iteration: 77,	Current solution: 112.3,	Taboo list: [112.7, 112.6, 112.5, 112.4, 112.3]
# Iteration: 78,	Current solution: 112.2,	Taboo list: [112.6, 112.5, 112.4, 112.3, 112.2]
# Iteration: 79,	Current solution: 112.1,	Taboo list: [112.5, 112.4, 112.3, 112.2, 112.1]
# Iteration: 80,	Current solution: 112.0,	Taboo list: [112.4, 112.3, 112.2, 112.1, 112.0]
# Iteration: 81,	Current solution: 111.9,	Taboo list: [112.3, 112.2, 112.1, 112.0, 111.9]
# Iteration: 82,	Current solution: 111.8,	Taboo list: [112.2, 112.1, 112.0, 111.9, 111.8]
# Iteration: 83,	Current solution: 111.7,	Taboo list: [112.1, 112.0, 111.9, 111.8, 111.7]
# Iteration: 84,	Current solution: 111.6,	Taboo list: [112.0, 111.9, 111.8, 111.7, 111.6]
# Iteration: 85,	Current solution: 111.5,	Taboo list: [111.9, 111.8, 111.7, 111.6, 111.5]
# Iteration: 86,	Current solution: 111.4,	Taboo list: [111.8, 111.7, 111.6, 111.5, 111.4]
# Iteration: 87,	Current solution: 111.3,	Taboo list: [111.7, 111.6, 111.5, 111.4, 111.3]
# Iteration: 88,	Current solution: 111.2,	Taboo list: [111.6, 111.5, 111.4, 111.3, 111.2]
# Iteration: 89,	Current solution: 111.1,	Taboo list: [111.5, 111.4, 111.3, 111.2, 111.1]
# Iteration: 90,	Current solution: 111.0,	Taboo list: [111.4, 111.3, 111.2, 111.1, 111.0]
# Iteration: 91,	Current solution: 110.9,	Taboo list: [111.3, 111.2, 111.1, 111.0, 110.9]
# Iteration: 92,	Current solution: 110.8,	Taboo list: [111.2, 111.1, 111.0, 110.9, 110.8]
# Iteration: 93,	Current solution: 110.7,	Taboo list: [111.1, 111.0, 110.9, 110.8, 110.7]
# Iteration: 94,	Current solution: 110.6,	Taboo list: [111.0, 110.9, 110.8, 110.7, 110.6]
# Iteration: 95,	Current solution: 110.5,	Taboo list: [110.9, 110.8, 110.7, 110.6, 110.5]
# Iteration: 96,	Current solution: 110.4,	Taboo list: [110.8, 110.7, 110.6, 110.5, 110.4]
# Iteration: 97,	Current solution: 110.3,	Taboo list: [110.7, 110.6, 110.5, 110.4, 110.3]
# Iteration: 98,	Current solution: 110.2,	Taboo list: [110.6, 110.5, 110.4, 110.3, 110.2]
# Iteration: 99,	Current solution: 110.1,	Taboo list: [110.5, 110.4, 110.3, 110.2, 110.1]
# Iteration: 100,	Current solution: 110.0,	Taboo list: [110.4, 110.3, 110.2, 110.1, 110.0]
# Iteration: 101,	Current solution: 109.9,	Taboo list: [110.3, 110.2, 110.1, 110.0, 109.9]
# Iteration: 102,	Current solution: 109.8,	Taboo list: [110.2, 110.1, 110.0, 109.9, 109.8]
# Iteration: 103,	Current solution: 109.7,	Taboo list: [110.1, 110.0, 109.9, 109.8, 109.7]
# Iteration: 104,	Current solution: 109.6,	Taboo list: [110.0, 109.9, 109.8, 109.7, 109.6]
# Iteration: 105,	Current solution: 109.5,	Taboo list: [109.9, 109.8, 109.7, 109.6, 109.5]
# Iteration: 106,	Current solution: 109.4,	Taboo list: [109.8, 109.7, 109.6, 109.5, 109.4]
# Iteration: 107,	Current solution: 109.3,	Taboo list: [109.7, 109.6, 109.5, 109.4, 109.3]
# Iteration: 108,	Current solution: 109.2,	Taboo list: [109.6, 109.5, 109.4, 109.3, 109.2]
# Iteration: 109,	Current solution: 109.1,	Taboo list: [109.5, 109.4, 109.3, 109.2, 109.1]
# Iteration: 110,	Current solution: 109.0,	Taboo list: [109.4, 109.3, 109.2, 109.1, 109.0]
# Iteration: 111,	Current solution: 108.9,	Taboo list: [109.3, 109.2, 109.1, 109.0, 108.9]
# Iteration: 112,	Current solution: 108.8,	Taboo list: [109.2, 109.1, 109.0, 108.9, 108.8]
# Iteration: 113,	Current solution: 108.7,	Taboo list: [109.1, 109.0, 108.9, 108.8, 108.7]
# Iteration: 114,	Current solution: 108.6,	Taboo list: [109.0, 108.9, 108.8, 108.7, 108.6]
# Iteration: 115,	Current solution: 108.5,	Taboo list: [108.9, 108.8, 108.7, 108.6, 108.5]
# Iteration: 116,	Current solution: 108.4,	Taboo list: [108.8, 108.7, 108.6, 108.5, 108.4]
# Iteration: 117,	Current solution: 108.3,	Taboo list: [108.7, 108.6, 108.5, 108.4, 108.3]
# Iteration: 118,	Current solution: 108.2,	Taboo list: [108.6, 108.5, 108.4, 108.3, 108.2]
# Iteration: 119,	Current solution: 108.1,	Taboo list: [108.5, 108.4, 108.3, 108.2, 108.1]
# Iteration: 120,	Current solution: 108.0,	Taboo list: [108.4, 108.3, 108.2, 108.1, 108.0]
# Iteration: 121,	Current solution: 107.9,	Taboo list: [108.3, 108.2, 108.1, 108.0, 107.9]
# Iteration: 122,	Current solution: 107.8,	Taboo list: [108.2, 108.1, 108.0, 107.9, 107.8]
# Iteration: 123,	Current solution: 107.7,	Taboo list: [108.1, 108.0, 107.9, 107.8, 107.7]
# Iteration: 124,	Current solution: 107.6,	Taboo list: [108.0, 107.9, 107.8, 107.7, 107.6]
# Iteration: 125,	Current solution: 107.5,	Taboo list: [107.9, 107.8, 107.7, 107.6, 107.5]
# Iteration: 126,	Current solution: 107.4,	Taboo list: [107.8, 107.7, 107.6, 107.5, 107.4]
# Iteration: 127,	Current solution: 107.3,	Taboo list: [107.7, 107.6, 107.5, 107.4, 107.3]
# Iteration: 128,	Current solution: 107.2,	Taboo list: [107.6, 107.5, 107.4, 107.3, 107.2]
# Iteration: 129,	Current solution: 107.1,	Taboo list: [107.5, 107.4, 107.3, 107.2, 107.1]
# Iteration: 130,	Current solution: 107.0,	Taboo list: [107.4, 107.3, 107.2, 107.1, 107.0]
# Iteration: 131,	Current solution: 106.9,	Taboo list: [107.3, 107.2, 107.1, 107.0, 106.9]
# Iteration: 132,	Current solution: 106.8,	Taboo list: [107.2, 107.1, 107.0, 106.9, 106.8]
# Iteration: 133,	Current solution: 106.7,	Taboo list: [107.1, 107.0, 106.9, 106.8, 106.7]
# Iteration: 134,	Current solution: 106.6,	Taboo list: [107.0, 106.9, 106.8, 106.7, 106.6]
# Iteration: 135,	Current solution: 106.5,	Taboo list: [106.9, 106.8, 106.7, 106.6, 106.5]
# Iteration: 136,	Current solution: 106.4,	Taboo list: [106.8, 106.7, 106.6, 106.5, 106.4]
# Iteration: 137,	Current solution: 106.3,	Taboo list: [106.7, 106.6, 106.5, 106.4, 106.3]
# Iteration: 138,	Current solution: 106.2,	Taboo list: [106.6, 106.5, 106.4, 106.3, 106.2]
# Iteration: 139,	Current solution: 106.1,	Taboo list: [106.5, 106.4, 106.3, 106.2, 106.1]
# Iteration: 140,	Current solution: 106.0,	Taboo list: [106.4, 106.3, 106.2, 106.1, 106.0]
# Iteration: 141,	Current solution: 105.9,	Taboo list: [106.3, 106.2, 106.1, 106.0, 105.9]
# Iteration: 142,	Current solution: 105.8,	Taboo list: [106.2, 106.1, 106.0, 105.9, 105.8]
# Iteration: 143,	Current solution: 105.7,	Taboo list: [106.1, 106.0, 105.9, 105.8, 105.7]
# Iteration: 144,	Current solution: 105.6,	Taboo list: [106.0, 105.9, 105.8, 105.7, 105.6]
# Iteration: 145,	Current solution: 105.5,	Taboo list: [105.9, 105.8, 105.7, 105.6, 105.5]
# Iteration: 146,	Current solution: 105.4,	Taboo list: [105.8, 105.7, 105.6, 105.5, 105.4]
# Iteration: 147,	Current solution: 105.3,	Taboo list: [105.7, 105.6, 105.5, 105.4, 105.3]
# Iteration: 148,	Current solution: 105.2,	Taboo list: [105.6, 105.5, 105.4, 105.3, 105.2]
# Iteration: 149,	Current solution: 105.1,	Taboo list: [105.5, 105.4, 105.3, 105.2, 105.1]
# Iteration: 150,	Current solution: 105.0,	Taboo list: [105.4, 105.3, 105.2, 105.1, 105.0]
# Iteration: 151,	Current solution: 104.9,	Taboo list: [105.3, 105.2, 105.1, 105.0, 104.9]
# Iteration: 152,	Current solution: 104.8,	Taboo list: [105.2, 105.1, 105.0, 104.9, 104.8]
# Iteration: 153,	Current solution: 104.7,	Taboo list: [105.1, 105.0, 104.9, 104.8, 104.7]
# Iteration: 154,	Current solution: 104.6,	Taboo list: [105.0, 104.9, 104.8, 104.7, 104.6]
# Iteration: 155,	Current solution: 104.5,	Taboo list: [104.9, 104.8, 104.7, 104.6, 104.5]
# Iteration: 156,	Current solution: 104.4,	Taboo list: [104.8, 104.7, 104.6, 104.5, 104.4]
# Iteration: 157,	Current solution: 104.3,	Taboo list: [104.7, 104.6, 104.5, 104.4, 104.3]
# Iteration: 158,	Current solution: 104.2,	Taboo list: [104.6, 104.5, 104.4, 104.3, 104.2]
# Iteration: 159,	Current solution: 104.1,	Taboo list: [104.5, 104.4, 104.3, 104.2, 104.1]
# Iteration: 160,	Current solution: 104.0,	Taboo list: [104.4, 104.3, 104.2, 104.1, 104.0]
# Iteration: 161,	Current solution: 103.9,	Taboo list: [104.3, 104.2, 104.1, 104.0, 103.9]
# Iteration: 162,	Current solution: 103.8,	Taboo list: [104.2, 104.1, 104.0, 103.9, 103.8]
# Iteration: 163,	Current solution: 103.7,	Taboo list: [104.1, 104.0, 103.9, 103.8, 103.7]
# Iteration: 164,	Current solution: 103.6,	Taboo list: [104.0, 103.9, 103.8, 103.7, 103.6]
# Iteration: 165,	Current solution: 103.5,	Taboo list: [103.9, 103.8, 103.7, 103.6, 103.5]
# Iteration: 166,	Current solution: 103.4,	Taboo list: [103.8, 103.7, 103.6, 103.5, 103.4]
# Iteration: 167,	Current solution: 103.3,	Taboo list: [103.7, 103.6, 103.5, 103.4, 103.3]
# Iteration: 168,	Current solution: 103.2,	Taboo list: [103.6, 103.5, 103.4, 103.3, 103.2]
# Iteration: 169,	Current solution: 103.1,	Taboo list: [103.5, 103.4, 103.3, 103.2, 103.1]
# Iteration: 170,	Current solution: 103.0,	Taboo list: [103.4, 103.3, 103.2, 103.1, 103.0]
# Iteration: 171,	Current solution: 102.9,	Taboo list: [103.3, 103.2, 103.1, 103.0, 102.9]
# Iteration: 172,	Current solution: 102.8,	Taboo list: [103.2, 103.1, 103.0, 102.9, 102.8]
# Iteration: 173,	Current solution: 102.7,	Taboo list: [103.1, 103.0, 102.9, 102.8, 102.7]
# Iteration: 174,	Current solution: 102.6,	Taboo list: [103.0, 102.9, 102.8, 102.7, 102.6]
# Iteration: 175,	Current solution: 102.5,	Taboo list: [102.9, 102.8, 102.7, 102.6, 102.5]
# Iteration: 176,	Current solution: 102.4,	Taboo list: [102.8, 102.7, 102.6, 102.5, 102.4]
# Iteration: 177,	Current solution: 102.3,	Taboo list: [102.7, 102.6, 102.5, 102.4, 102.3]
# Iteration: 178,	Current solution: 102.2,	Taboo list: [102.6, 102.5, 102.4, 102.3, 102.2]
# Iteration: 179,	Current solution: 102.1,	Taboo list: [102.5, 102.4, 102.3, 102.2, 102.1]
# Iteration: 180,	Current solution: 102.0,	Taboo list: [102.4, 102.3, 102.2, 102.1, 102.0]
# Iteration: 181,	Current solution: 101.9,	Taboo list: [102.3, 102.2, 102.1, 102.0, 101.9]
# Iteration: 182,	Current solution: 101.8,	Taboo list: [102.2, 102.1, 102.0, 101.9, 101.8]
# Iteration: 183,	Current solution: 101.7,	Taboo list: [102.1, 102.0, 101.9, 101.8, 101.7]
# Iteration: 184,	Current solution: 101.6,	Taboo list: [102.0, 101.9, 101.8, 101.7, 101.6]
# Iteration: 185,	Current solution: 101.5,	Taboo list: [101.9, 101.8, 101.7, 101.6, 101.5]
# Iteration: 186,	Current solution: 101.4,	Taboo list: [101.8, 101.7, 101.6, 101.5, 101.4]
# Iteration: 187,	Current solution: 101.3,	Taboo list: [101.7, 101.6, 101.5, 101.4, 101.3]
# Iteration: 188,	Current solution: 101.2,	Taboo list: [101.6, 101.5, 101.4, 101.3, 101.2]
# Iteration: 189,	Current solution: 101.1,	Taboo list: [101.5, 101.4, 101.3, 101.2, 101.1]
# Iteration: 190,	Current solution: 101.0,	Taboo list: [101.4, 101.3, 101.2, 101.1, 101.0]
# Iteration: 191,	Current solution: 101.0,	Taboo list: [101.3, 101.2, 101.1, 101.0, 100.9]
# Iteration: 192,	Current solution: 101.0,	Taboo list: [101.3, 101.2, 101.1, 101.0, 100.9]

# %%
plot_taboo_search_metaheuristic(f, (-5, 150), results)

# %%
# Imports my plotting module
import batch_plotting as batch_plt

# %%
# Batch test taboo search with different starting points
starting_point_results = []
for start_x in range(80, 120):
    result = taboo_search(f, start_x, stop_function, taboo_memory, get_neighbourhood, False, stop_args={"max_i": max_i}, neighbourhood_args={"step_size": step_size})
    starting_point_results.append({"x": start_x, "y": result[1]})
batch_plt.plot_2d_batch_accuracy("finish point (x_n)", "starting point (x_0)", 101, starting_point_results)

# %%
# Batch test gradient descent with different max_iterations (over 3 starting points)
starting_points = [80, 101, 120]
for starting_point in starting_points:
    iteration_results = []
    for max_i in range(40):
        max_iter = (max_i+1)*5
        result = taboo_search(f, starting_point, stop_function, taboo_memory, get_neighbourhood, False, stop_args={"max_i": max_iter}, neighbourhood_args={"step_size": step_size})
        iteration_results.append({"x": max_iter, "y": result[1]})

    print("Starting at {}".format(starting_point))
    batch_plt.plot_2d_batch_accuracy("finish point (x_n)", "iterations (max_i)", 101, iteration_results)
# Out:
# Starting at 80
# Starting at 101
# Starting at 120

# %%
# Batch test for step size
for starting_point in starting_points:
    iteration_results = []
    for s in range(40):
        step = (s+1)/20
        result = taboo_search(f, starting_point, stop_function, taboo_memory, get_neighbourhood, False, stop_args={"max_i": max_iter}, neighbourhood_args={"step_size": step})
        iteration_results.append({"x": step, "y": result[1]})

    print("Starting at {}".format(starting_point))
    batch_plt.plot_2d_batch_accuracy("finish point (x_n)", "step size", 101, iteration_results)
# Out:
# Starting at 80
# Starting at 101
# Starting at 120

# %%
# Batch test for taboo memory
for starting_point in starting_points:
    iteration_results = []
    for memory in range(1, 5):
        result = taboo_search(f, starting_point, stop_function, memory, get_neighbourhood, False, stop_args={"max_i": max_iter}, neighbourhood_args={"step_size": step_size})
        iteration_results.append({"x": memory, "y": result[1]})

    print("Starting at {}".format(starting_point))
    batch_plt.plot_2d_batch_accuracy("finish point (x_n)", "taboo memory", 101, iteration_results)
# Out:
# Starting at 80
# Starting at 101
# Starting at 120
