# %%
import random
import math
import numpy as np
import sys

sys.path.extend(["../../modules", "../"])

# %%
title = ["green", "red", "blue", "yellow", "brown", "purple"]
rhs = [10, 6, 10, 18, 8, 12]

# If any constraint is False then False, otherwise if every constraint is True then True. 
def check_all_constraints(xs, constraints):
    for constraint in constraints:
        c = constraint(xs)
        if (c[1] > c[2]):
            #print("({} constraint fails)".format(c[0]))
            return False
    return True

# Prints all constraint progress 
def print_all_constraints(xs, constraints):
    for constraint in constraints:
        c = constraint(xs)
        print("{} constraint: {} <= {}".format(c[0], round(c[1], 3), c[2]))

# %%
###### Gradient Descent stuff
'''
        pds          :   An object of partial differentials problem function which is being investigated by the metaheuristic.
        constraints  :   An array of constraint functions which return true or false.
        GD_defaults  :   Default values of following parameters: x_0s, max_i, step_m, e_g, e_x 
        max_i        :   The maximum amount of iterations.
        x_0s         :   An object of starting values, one per dimension.
        step_m       :   The multipler of the step size.
        e_g          :   The tolerance of the gradient.
        e_x          :   The tolerance of the difference in x.
'''

class GD_defaults:
    def __init__(self, is_maximisation, x_0s, max_i, step_m, e_g, e_x):
        self.is_maximisation = is_maximisation
        self.x_0s = x_0s
        self.max_i = max_i
        self.step_m = step_m
        self.e_g = e_g
        self.e_x = e_x

def gradient_descent(pds, constraints, DEFAULTS, is_maximisation = None, x_0s = None, max_i = None, step_m = None, e_g = None, e_x = None, print_workings = False):
    # Default parameters
    is_maximisation = DEFAULTS.is_maximisation if is_maximisation is None else is_maximisation
    x_0s = DEFAULTS.x_0s if x_0s is None else x_0s
    max_i = DEFAULTS.max_i if max_i is None else max_i
    step_m = DEFAULTS.step_m if step_m is None else step_m
    e_g = DEFAULTS.e_g if e_g is None else e_g
    e_x = DEFAULTS.e_x if e_x is None else e_x
    
    # Set the current x and create a way of storing the previous steps.
    current_xs = x_0s
    gs = {d: round(pds[d](v), 3) for d, v in current_xs.items()}
    step_array = []
    
    # Whether to print the workings
    if (print_workings == True):
        print("--------------------------------------------------------------------------------------------\nIteration\tX\tg\tdiff\nStart (0)\t{}\t{}\t{}".format({k: round(v, 3) for k, v in current_xs.items()}, gs, "N/A"))
        
    
    # Loop for a maximum of max_i
    for i in range(max_i):
        # Check if constraints are satisfied before continuing
        if (not check_all_constraints(current_xs, constraints)):
            if (i == 0):
                return([], False)
            current_xs = step_array[-1]
            step_array.pop()
            break
        # Set previous x
        step_array.append(current_xs)
        # Find the current x
        if (not is_maximisation):
            step_m = -step_m
        current_xs = {d: round(v + step_m*gs[d], 3) for d, v in current_xs.items()}
        # Get a new gradient
        gs = {d: round(pds[d](v), 3) for d, v in current_xs.items()}
        gavg = 0
        for d, v in gs.items():
            gavg += v
        gavg /= len(gs)
        # Find difference in x
        diff = 0
        for d, v in current_xs.items():
            diff += (v - step_array[i][d])**2
        diff = round(math.sqrt(diff), 3)
        # Whether to print the workings
        if (print_workings == True):
            print("{}\t\t{}\t{}\t{}".format(i+1, {k: round(v, 3) for k, v in current_xs.items()}, gs, diff))
        # Check if either of the tolerance conditions are met, if so stop the loop. 
        if (abs(gavg) < e_g or abs(diff) < e_x):
            break
    
    # Add final x to step_array
    step_array.append(current_xs)
    # Return a tuple of all steps and final answer
    return (step_array, current_xs)

# %%
def f(xs):
    return 3*xs["x1"]+5*xs["x2"]+4*xs["x3"]+xs["x4"]

pds = {"x1": lambda v: 3, "x2": lambda v: 5, "x3": lambda v: 4, "x4": lambda v: 1}

x_0s = {"x1": 0, "x2": 0, "x3": 0, "x4": 0}

def x1_non_neg_constraint(xs):
    return ("x1 not -ve", 0, xs["x1"])
def x2_non_neg_constraint(xs):
    return ("x2 not -ve", 0, xs["x2"])
def x3_non_neg_constraint(xs):
    return ("x3 not -ve", 0, xs["x3"])
def x4_non_neg_constraint(xs):
    return ("x4 not -ve", 0, xs["x4"])
def green_wool_constraint(xs):
    return ("green", xs["x1"]+2*xs["x2"]+xs["x3"]+xs["x4"], 10)
def red_wool_constraint(xs):
    return ("red", 2*xs["x1"]+xs["x2"]+2*xs["x3"]+xs["x4"], 6)
def blue_wool_constraint(xs):
    return ("blue", 3*xs["x1"]+xs["x2"], 10)
def yellow_wool_constraint(xs):
    return ("yellow", xs["x1"]+4*xs["x2"], 18)
def brown_wool_constraint(xs):
    return ("brown", xs["x3"]+3*xs["x4"], 8)
def purple_wool_constraint(xs):
    return ("purple", 3*xs["x3"]+3*xs["x4"], 12)

constraints = [x1_non_neg_constraint, x2_non_neg_constraint, x3_non_neg_constraint, x4_non_neg_constraint, green_wool_constraint, red_wool_constraint, blue_wool_constraint, yellow_wool_constraint, brown_wool_constraint, purple_wool_constraint]

max_i = 1000

step_m = 0.1

e_g = 0.001

e_x = 0.001

DEFAULTS = GD_defaults(True, x_0s, max_i, step_m, e_g, e_x)

# %%
results = gradient_descent(pds, constraints, DEFAULTS, print_workings=True)
# Out:
# --------------------------------------------------------------------------------------------
# Iteration	X	g	diff
# Start (0)	{'x1': 0, 'x2': 0, 'x3': 0, 'x4': 0}	{'x1': 3, 'x2': 5, 'x3': 4, 'x4': 1}	N/A
# 1		{'x1': 0.3, 'x4': 0.1, 'x3': 0.4, 'x2': 0.5}	{'x1': 3, 'x4': 1, 'x3': 4, 'x2': 5}	0.714
# 2		{'x1': 0.6, 'x2': 1.0, 'x3': 0.8, 'x4': 0.2}	{'x1': 3, 'x2': 5, 'x3': 4, 'x4': 1}	0.714
# 3		{'x1': 0.9, 'x4': 0.3, 'x3': 1.2, 'x2': 1.5}	{'x1': 3, 'x4': 1, 'x3': 4, 'x2': 5}	0.714
# 4		{'x1': 1.2, 'x2': 2.0, 'x3': 1.6, 'x4': 0.4}	{'x1': 3, 'x2': 5, 'x3': 4, 'x4': 1}	0.714

# %%
for i in range(len(results[0])):
    print("Iter: ", i)
    print_all_constraints(results[0][i], constraints)
# Out:
# Iter:  0
# x1 not -ve constraint: 0 <= 0
# x2 not -ve constraint: 0 <= 0
# x3 not -ve constraint: 0 <= 0
# x4 not -ve constraint: 0 <= 0
# green constraint: 0 <= 10
# red constraint: 0 <= 6
# blue constraint: 0 <= 10
# yellow constraint: 0 <= 18
# brown constraint: 0 <= 8
# purple constraint: 0 <= 12
# Iter:  1
# x1 not -ve constraint: 0 <= 0.3
# x2 not -ve constraint: 0 <= 0.5
# x3 not -ve constraint: 0 <= 0.4
# x4 not -ve constraint: 0 <= 0.1
# green constraint: 1.8 <= 10
# red constraint: 2.0 <= 6
# blue constraint: 1.4 <= 10
# yellow constraint: 2.3 <= 18
# brown constraint: 0.7 <= 8
# purple constraint: 1.5 <= 12
# Iter:  2
# x1 not -ve constraint: 0 <= 0.6
# x2 not -ve constraint: 0 <= 1.0
# x3 not -ve constraint: 0 <= 0.8
# x4 not -ve constraint: 0 <= 0.2
# green constraint: 3.6 <= 10
# red constraint: 4.0 <= 6
# blue constraint: 2.8 <= 10
# yellow constraint: 4.6 <= 18
# brown constraint: 1.4 <= 8
# purple constraint: 3.0 <= 12
# Iter:  3
# x1 not -ve constraint: 0 <= 0.9
# x2 not -ve constraint: 0 <= 1.5
# x3 not -ve constraint: 0 <= 1.2
# x4 not -ve constraint: 0 <= 0.3
# green constraint: 5.4 <= 10
# red constraint: 6.0 <= 6
# blue constraint: 4.2 <= 10
# yellow constraint: 6.9 <= 18
# brown constraint: 2.1 <= 8
# purple constraint: 4.5 <= 12

# %%
# Imports my plotting module
import batch_plotting as batch_plt

# %%
# Batch testing start position
starting_point_results = []
spiral = n_dim_spiral({"x1": 0, "x2": 0, "x3": 0, "x4": 0}, 2000, 0.05)
for i in range(len(spiral)):
    ps = spiral[i]
    result = gradient_descent(pds, constraints, DEFAULTS, x_0s = ps)
    starting_point_results.append({"x": i, "y": f(result[1]) if result[1] is not False else False})

# %%
batch_plt.plot_2d_batch_accuracy("profit f(cx)", "starting point (cx)", False, starting_point_results)

# %%
spiral[0]
# Out:
# {'x1': 0, 'x2': 0, 'x3': 0, 'x4': 0}

# %%
starting_point_results
# Out:
# [{'x': 0, 'y': 15.3},
#  {'x': 1, 'y': 10.35},
#  {'x': 2, 'y': 10.4},
#  {'x': 3, 'y': 10.6},
#  {'x': 4, 'y': 10.85},
#  {'x': 5, 'y': 10.7},
#  {'x': 6, 'y': False},
#  {'x': 7, 'y': False},
#  {'x': 8, 'y': False},
#  {'x': 9, 'y': False},
#  {'x': 10, 'y': False},
#  {'x': 11, 'y': False},
#  {'x': 12, 'y': False},
#  {'x': 13, 'y': False},
#  {'x': 14, 'y': False},
#  {'x': 15, 'y': False},
#  {'x': 16, 'y': False},
#  {'x': 17, 'y': False},
#  {'x': 18, 'y': False},
#  {'x': 19, 'y': False},
#  {'x': 20, 'y': False},
#  {'x': 21, 'y': False},
#  {'x': 22, 'y': 11.0},
#  {'x': 23, 'y': 11.25},
#  {'x': 24, 'y': 11.5},
#  {'x': 25, 'y': 11.350000000000001},
#  {'x': 26, 'y': 11.200000000000001},
#  {'x': 27, 'y': False},
#  {'x': 28, 'y': False},
#  {'x': 29, 'y': False},
#  {'x': 30, 'y': False},
#  {'x': 31, 'y': False},
#  {'x': 32, 'y': False},
#  {'x': 33, 'y': False},
#  {'x': 34, 'y': False},
#  {'x': 35, 'y': False},
#  {'x': 36, 'y': False},
#  {'x': 37, 'y': False},
#  {'x': 38, 'y': False},
#  {'x': 39, 'y': False},
#  {'x': 40, 'y': False},
#  {'x': 41, 'y': False},
#  {'x': 42, 'y': False},
#  {'x': 43, 'y': False},
#  {'x': 44, 'y': False},
#  {'x': 45, 'y': False},
#  {'x': 46, 'y': False},
#  {'x': 47, 'y': False},
#  {'x': 48, 'y': False},
#  {'x': 49, 'y': False},
#  {'x': 50, 'y': False},
#  {'x': 51, 'y': False},
#  {'x': 52, 'y': False},
#  {'x': 53, 'y': False},
#  {'x': 54, 'y': False},
#  {'x': 55, 'y': False},
#  {'x': 56, 'y': False},
#  {'x': 57, 'y': 11.4},
#  {'x': 58, 'y': 11.65},
#  {'x': 59, 'y': 11.9},
#  {'x': 60, 'y': 12.15},
#  {'x': 61, 'y': 11.999999999999998},
#  {'x': 62, 'y': 11.85},
#  {'x': 63, 'y': 11.7},
#  {'x': 64, 'y': False},
#  {'x': 65, 'y': False},
#  {'x': 66, 'y': False},
#  {'x': 67, 'y': False},
#  {'x': 68, 'y': False},
#  {'x': 69, 'y': False},
#  {'x': 70, 'y': False},
#  {'x': 71, 'y': False},
#  {'x': 72, 'y': False},
#  {'x': 73, 'y': False},
#  {'x': 74, 'y': False},
#  {'x': 75, 'y': False},
#  {'x': 76, 'y': False},
#  {'x': 77, 'y': False},
#  {'x': 78, 'y': False},
#  {'x': 79, 'y': False},
#  {'x': 80, 'y': False},
#  {'x': 81, 'y': False},
#  {'x': 82, 'y': False},
#  {'x': 83, 'y': False},
#  {'x': 84, 'y': False},
#  {'x': 85, 'y': False},
#  {'x': 86, 'y': False},
#  {'x': 87, 'y': False},
#  {'x': 88, 'y': False},
#  {'x': 89, 'y': False},
#  {'x': 90, 'y': False},
#  {'x': 91, 'y': False},
#  {'x': 92, 'y': False},
#  {'x': 93, 'y': False},
#  {'x': 94, 'y': False},
#  {'x': 95, 'y': False},
#  {'x': 96, 'y': False},
#  {'x': 97, 'y': False},
#  {'x': 98, 'y': False},
#  {'x': 99, 'y': False},
#  {'x': 100, 'y': False},
#  {'x': 101, 'y': False},
#  {'x': 102, 'y': False},
#  {'x': 103, 'y': False},
#  {'x': 104, 'y': False},
#  {'x': 105, 'y': False},
#  {'x': 106, 'y': False},
#  {'x': 107, 'y': False},
#  {'x': 108, 'y': 11.8},
#  {'x': 109, 'y': 12.05},
#  {'x': 110, 'y': 12.3},
#  {'x': 111, 'y': 12.55},
#  {'x': 112, 'y': 12.8},
#  {'x': 113, 'y': 12.65},
#  {'x': 114, 'y': 12.5},
#  {'x': 115, 'y': 12.35},
#  {'x': 116, 'y': 12.200000000000001},
#  {'x': 117, 'y': False},
#  {'x': 118, 'y': False},
#  {'x': 119, 'y': False},
#  {'x': 120, 'y': False},
#  {'x': 121, 'y': False},
#  {'x': 122, 'y': False},
#  {'x': 123, 'y': False},
#  {'x': 124, 'y': False},
#  {'x': 125, 'y': False},
#  {'x': 126, 'y': False},
#  {'x': 127, 'y': False},
#  {'x': 128, 'y': False},
#  {'x': 129, 'y': False},
#  {'x': 130, 'y': False},
#  {'x': 131, 'y': False},
#  {'x': 132, 'y': False},
#  {'x': 133, 'y': False},
#  {'x': 134, 'y': False},
#  {'x': 135, 'y': False},
#  {'x': 136, 'y': False},
#  {'x': 137, 'y': False},
#  {'x': 138, 'y': False},
#  {'x': 139, 'y': False},
#  {'x': 140, 'y': False},
#  {'x': 141, 'y': False},
#  {'x': 142, 'y': False},
#  {'x': 143, 'y': False},
#  {'x': 144, 'y': False},
#  {'x': 145, 'y': False},
#  {'x': 146, 'y': False},
#  {'x': 147, 'y': False},
#  {'x': 148, 'y': False},
#  {'x': 149, 'y': False},
#  {'x': 150, 'y': False},
#  {'x': 151, 'y': False},
#  {'x': 152, 'y': False},
#  {'x': 153, 'y': False},
#  {'x': 154, 'y': False},
#  {'x': 155, 'y': False},
#  {'x': 156, 'y': False},
#  {'x': 157, 'y': False},
#  {'x': 158, 'y': False},
#  {'x': 159, 'y': False},
#  {'x': 160, 'y': False},
#  {'x': 161, 'y': False},
#  {'x': 162, 'y': False},
#  {'x': 163, 'y': False},
#  {'x': 164, 'y': False},
#  {'x': 165, 'y': False},
#  {'x': 166, 'y': False},
#  {'x': 167, 'y': False},
#  {'x': 168, 'y': False},
#  {'x': 169, 'y': False},
#  {'x': 170, 'y': False},
#  {'x': 171, 'y': False},
#  {'x': 172, 'y': False},
#  {'x': 173, 'y': False},
#  {'x': 174, 'y': False},
#  {'x': 175, 'y': False},
#  {'x': 176, 'y': 12.45},
#  {'x': 177, 'y': 12.7},
#  {'x': 178, 'y': 12.95},
#  {'x': 179, 'y': 13.2},
#  {'x': 180, 'y': 13.45},
#  {'x': 181, 'y': 13.3},
#  {'x': 182, 'y': 13.149999999999999},
#  {'x': 183, 'y': 13.0},
#  {'x': 184, 'y': 12.849999999999998},
#  {'x': 185, 'y': 12.7},
#  {'x': 186, 'y': False},
#  {'x': 187, 'y': False},
#  {'x': 188, 'y': False},
#  {'x': 189, 'y': False},
#  {'x': 190, 'y': False},
#  {'x': 191, 'y': False},
#  {'x': 192, 'y': False},
#  {'x': 193, 'y': False},
#  {'x': 194, 'y': False},
#  {'x': 195, 'y': False},
#  {'x': 196, 'y': False},
#  {'x': 197, 'y': False},
#  {'x': 198, 'y': False},
#  {'x': 199, 'y': False},
#  {'x': 200, 'y': False},
#  {'x': 201, 'y': False},
#  {'x': 202, 'y': False},
#  {'x': 203, 'y': False},
#  {'x': 204, 'y': False},
#  {'x': 205, 'y': False},
#  {'x': 206, 'y': False},
#  {'x': 207, 'y': False},
#  {'x': 208, 'y': False},
#  {'x': 209, 'y': False},
#  {'x': 210, 'y': False},
#  {'x': 211, 'y': False},
#  {'x': 212, 'y': False},
#  {'x': 213, 'y': False},
#  {'x': 214, 'y': False},
#  {'x': 215, 'y': False},
#  {'x': 216, 'y': False},
#  {'x': 217, 'y': False},
#  {'x': 218, 'y': False},
#  {'x': 219, 'y': False},
#  {'x': 220, 'y': False},
#  {'x': 221, 'y': False},
#  {'x': 222, 'y': False},
#  {'x': 223, 'y': False},
#  {'x': 224, 'y': False},
#  {'x': 225, 'y': False},
#  {'x': 226, 'y': False},
#  {'x': 227, 'y': False},
#  {'x': 228, 'y': False},
#  {'x': 229, 'y': False},
#  {'x': 230, 'y': False},
#  {'x': 231, 'y': False},
#  {'x': 232, 'y': False},
#  {'x': 233, 'y': False},
#  {'x': 234, 'y': False},
#  {'x': 235, 'y': False},
#  {'x': 236, 'y': False},
#  {'x': 237, 'y': False},
#  {'x': 238, 'y': False},
#  {'x': 239, 'y': False},
#  {'x': 240, 'y': False},
#  {'x': 241, 'y': False},
#  {'x': 242, 'y': False},
#  {'x': 243, 'y': False},
#  {'x': 244, 'y': False},
#  {'x': 245, 'y': False},
#  {'x': 246, 'y': False},
#  {'x': 247, 'y': False},
#  {'x': 248, 'y': False},
#  {'x': 249, 'y': False},
#  {'x': 250, 'y': False},
#  {'x': 251, 'y': False},
#  {'x': 252, 'y': False},
#  {'x': 253, 'y': False},
#  {'x': 254, 'y': False},
#  {'x': 255, 'y': False},
#  {'x': 256, 'y': False},
#  {'x': 257, 'y': False},
#  {'x': 258, 'y': False},
#  {'x': 259, 'y': 12.850000000000001},
#  {'x': 260, 'y': 13.1},
#  {'x': 261, 'y': 13.35},
#  {'x': 262, 'y': 13.6},
#  {'x': 263, 'y': 13.85},
#  {'x': 264, 'y': 14.1},
#  {'x': 265, 'y': 13.950000000000001},
#  {'x': 266, 'y': 13.8},
#  {'x': 267, 'y': 13.65},
#  {'x': 268, 'y': 13.5},
#  {'x': 269, 'y': 13.35},
#  {'x': 270, 'y': 13.200000000000001},
#  {'x': 271, 'y': False},
#  {'x': 272, 'y': False},
#  {'x': 273, 'y': False},
#  {'x': 274, 'y': False},
#  {'x': 275, 'y': False},
#  {'x': 276, 'y': False},
#  {'x': 277, 'y': False},
#  {'x': 278, 'y': False},
#  {'x': 279, 'y': False},
#  {'x': 280, 'y': False},
#  {'x': 281, 'y': False},
#  {'x': 282, 'y': False},
#  {'x': 283, 'y': False},
#  {'x': 284, 'y': False},
#  {'x': 285, 'y': False},
#  {'x': 286, 'y': False},
#  {'x': 287, 'y': False},
#  {'x': 288, 'y': False},
#  {'x': 289, 'y': False},
#  {'x': 290, 'y': False},
#  {'x': 291, 'y': False},
#  {'x': 292, 'y': False},
#  {'x': 293, 'y': False},
#  {'x': 294, 'y': False},
#  {'x': 295, 'y': False},
#  {'x': 296, 'y': False},
#  {'x': 297, 'y': False},
#  {'x': 298, 'y': False},
#  {'x': 299, 'y': False},
#  {'x': 300, 'y': False},
#  {'x': 301, 'y': False},
#  {'x': 302, 'y': False},
#  {'x': 303, 'y': False},
#  {'x': 304, 'y': False},
#  {'x': 305, 'y': False},
#  {'x': 306, 'y': False},
#  {'x': 307, 'y': False},
#  {'x': 308, 'y': False},
#  {'x': 309, 'y': False},
#  {'x': 310, 'y': False},
#  {'x': 311, 'y': False},
#  {'x': 312, 'y': False},
#  {'x': 313, 'y': False},
#  {'x': 314, 'y': False},
#  {'x': 315, 'y': False},
#  {'x': 316, 'y': False},
#  {'x': 317, 'y': False},
#  {'x': 318, 'y': False},
#  {'x': 319, 'y': False},
#  {'x': 320, 'y': False},
#  {'x': 321, 'y': False},
#  {'x': 322, 'y': False},
#  {'x': 323, 'y': False},
#  {'x': 324, 'y': False},
#  {'x': 325, 'y': False},
#  {'x': 326, 'y': False},
#  {'x': 327, 'y': False},
#  {'x': 328, 'y': False},
#  {'x': 329, 'y': False},
#  {'x': 330, 'y': False},
#  {'x': 331, 'y': False},
#  {'x': 332, 'y': False},
#  {'x': 333, 'y': False},
#  {'x': 334, 'y': False},
#  {'x': 335, 'y': False},
#  {'x': 336, 'y': False},
#  {'x': 337, 'y': False},
#  {'x': 338, 'y': False},
#  {'x': 339, 'y': False},
#  {'x': 340, 'y': False},
#  {'x': 341, 'y': False},
#  {'x': 342, 'y': False},
#  {'x': 343, 'y': False},
#  {'x': 344, 'y': False},
#  {'x': 345, 'y': False},
#  {'x': 346, 'y': False},
#  {'x': 347, 'y': False},
#  {'x': 348, 'y': False},
#  {'x': 349, 'y': False},
#  {'x': 350, 'y': False},
#  {'x': 351, 'y': False},
#  {'x': 352, 'y': False},
#  {'x': 353, 'y': False},
#  {'x': 354, 'y': False},
#  {'x': 355, 'y': False},
#  {'x': 356, 'y': False},
#  {'x': 357, 'y': False},
#  {'x': 358, 'y': 13.25},
#  {'x': 359, 'y': 13.5},
#  {'x': 360, 'y': 13.75},
#  {'x': 361, 'y': 14.0},
#  {'x': 362, 'y': 14.25},
#  {'x': 363, 'y': 9.399999999999999},
#  {'x': 364, 'y': 9.649999999999999},
#  {'x': 365, 'y': 14.6},
#  {'x': 366, 'y': 14.450000000000001},
#  {'x': 367, 'y': 14.3},
#  {'x': 368, 'y': 14.15},
#  {'x': 369, 'y': 14.0},
#  {'x': 370, 'y': 13.85},
#  {'x': 371, 'y': 13.700000000000001},
#  {'x': 372, 'y': False},
#  {'x': 373, 'y': False},
#  {'x': 374, 'y': False},
#  {'x': 375, 'y': False},
#  {'x': 376, 'y': False},
#  {'x': 377, 'y': False},
#  {'x': 378, 'y': False},
#  {'x': 379, 'y': False},
#  {'x': 380, 'y': False},
#  {'x': 381, 'y': False},
#  {'x': 382, 'y': False},
#  {'x': 383, 'y': False},
#  {'x': 384, 'y': False},
#  {'x': 385, 'y': False},
#  {'x': 386, 'y': False},
#  {'x': 387, 'y': False},
#  {'x': 388, 'y': False},
#  {'x': 389, 'y': False},
#  {'x': 390, 'y': False},
#  {'x': 391, 'y': False},
#  {'x': 392, 'y': False},
#  {'x': 393, 'y': False},
#  {'x': 394, 'y': False},
#  {'x': 395, 'y': False},
#  {'x': 396, 'y': False},
#  {'x': 397, 'y': False},
#  {'x': 398, 'y': False},
#  {'x': 399, 'y': False},
#  {'x': 400, 'y': False},
#  {'x': 401, 'y': False},
#  {'x': 402, 'y': False},
#  {'x': 403, 'y': False},
#  {'x': 404, 'y': False},
#  {'x': 405, 'y': False},
#  {'x': 406, 'y': False},
#  {'x': 407, 'y': False},
#  {'x': 408, 'y': False},
#  {'x': 409, 'y': False},
#  {'x': 410, 'y': False},
#  {'x': 411, 'y': False},
#  {'x': 412, 'y': False},
#  {'x': 413, 'y': False},
#  {'x': 414, 'y': False},
#  {'x': 415, 'y': False},
#  {'x': 416, 'y': False},
#  {'x': 417, 'y': False},
#  {'x': 418, 'y': False},
#  {'x': 419, 'y': False},
#  {'x': 420, 'y': False},
#  {'x': 421, 'y': False},
#  {'x': 422, 'y': False},
#  {'x': 423, 'y': False},
#  {'x': 424, 'y': False},
#  {'x': 425, 'y': False},
#  {'x': 426, 'y': False},
#  {'x': 427, 'y': False},
#  {'x': 428, 'y': False},
#  {'x': 429, 'y': False},
#  {'x': 430, 'y': False},
#  {'x': 431, 'y': False},
#  {'x': 432, 'y': False},
#  {'x': 433, 'y': False},
#  {'x': 434, 'y': False},
#  {'x': 435, 'y': False},
#  {'x': 436, 'y': False},
#  {'x': 437, 'y': False},
#  {'x': 438, 'y': False},
#  {'x': 439, 'y': False},
#  {'x': 440, 'y': False},
#  {'x': 441, 'y': False},
#  {'x': 442, 'y': False},
#  {'x': 443, 'y': False},
#  {'x': 444, 'y': False},
#  {'x': 445, 'y': False},
#  {'x': 446, 'y': False},
#  {'x': 447, 'y': False},
#  {'x': 448, 'y': False},
#  {'x': 449, 'y': False},
#  {'x': 450, 'y': False},
#  {'x': 451, 'y': False},
#  {'x': 452, 'y': False},
#  {'x': 453, 'y': False},
#  {'x': 454, 'y': False},
#  {'x': 455, 'y': False},
#  {'x': 456, 'y': False},
#  {'x': 457, 'y': False},
#  {'x': 458, 'y': False},
#  {'x': 459, 'y': False},
#  {'x': 460, 'y': False},
#  {'x': 461, 'y': False},
#  {'x': 462, 'y': False},
#  {'x': 463, 'y': False},
#  {'x': 464, 'y': False},
#  {'x': 465, 'y': False},
#  {'x': 466, 'y': False},
#  {'x': 467, 'y': False},
#  {'x': 468, 'y': False},
#  {'x': 469, 'y': False},
#  {'x': 470, 'y': False},
#  {'x': 471, 'y': False},
#  {'x': 472, 'y': False},
#  {'x': 473, 'y': 8.55},
#  {'x': 474, 'y': 8.8},
#  {'x': 475, 'y': 9.05},
#  {'x': 476, 'y': 9.3},
#  {'x': 477, 'y': 9.55},
#  {'x': 478, 'y': 9.8},
#  {'x': 479, 'y': 10.05},
#  {'x': 480, 'y': 10.3},
#  {'x': 481, 'y': 10.15},
#  {'x': 482, 'y': 10.0},
#  {'x': 483, 'y': 9.850000000000001},
#  {'x': 484, 'y': 14.799999999999999},
#  {'x': 485, 'y': 14.65},
#  {'x': 486, 'y': 14.499999999999998},
#  {'x': 487, 'y': 14.35},
#  {'x': 488, 'y': 14.200000000000001},
#  {'x': 489, 'y': False},
#  {'x': 490, 'y': False},
#  {'x': 491, 'y': False},
#  {'x': 492, 'y': False},
#  {'x': 493, 'y': False},
#  {'x': 494, 'y': False},
#  {'x': 495, 'y': False},
#  {'x': 496, 'y': False},
#  {'x': 497, 'y': False},
#  {'x': 498, 'y': False},
#  {'x': 499, 'y': False},
#  {'x': 500, 'y': False},
#  {'x': 501, 'y': False},
#  {'x': 502, 'y': False},
#  {'x': 503, 'y': False},
#  {'x': 504, 'y': False},
#  {'x': 505, 'y': False},
#  {'x': 506, 'y': False},
#  {'x': 507, 'y': False},
#  {'x': 508, 'y': False},
#  {'x': 509, 'y': False},
#  {'x': 510, 'y': False},
#  {'x': 511, 'y': False},
#  {'x': 512, 'y': False},
#  {'x': 513, 'y': False},
#  {'x': 514, 'y': False},
#  {'x': 515, 'y': False},
#  {'x': 516, 'y': False},
#  {'x': 517, 'y': False},
#  {'x': 518, 'y': False},
#  {'x': 519, 'y': False},
#  {'x': 520, 'y': False},
#  {'x': 521, 'y': False},
#  {'x': 522, 'y': False},
#  {'x': 523, 'y': False},
#  {'x': 524, 'y': False},
#  {'x': 525, 'y': False},
#  {'x': 526, 'y': False},
#  {'x': 527, 'y': False},
#  {'x': 528, 'y': False},
#  {'x': 529, 'y': False},
#  {'x': 530, 'y': False},
#  {'x': 531, 'y': False},
#  {'x': 532, 'y': False},
#  {'x': 533, 'y': False},
#  {'x': 534, 'y': False},
#  {'x': 535, 'y': False},
#  {'x': 536, 'y': False},
#  {'x': 537, 'y': False},
#  {'x': 538, 'y': False},
#  {'x': 539, 'y': False},
#  {'x': 540, 'y': False},
#  {'x': 541, 'y': False},
#  {'x': 542, 'y': False},
#  {'x': 543, 'y': False},
#  {'x': 544, 'y': False},
#  {'x': 545, 'y': False},
#  {'x': 546, 'y': False},
#  {'x': 547, 'y': False},
#  {'x': 548, 'y': False},
#  {'x': 549, 'y': False},
#  {'x': 550, 'y': False},
#  {'x': 551, 'y': False},
#  {'x': 552, 'y': False},
#  {'x': 553, 'y': False},
#  {'x': 554, 'y': False},
#  {'x': 555, 'y': False},
#  {'x': 556, 'y': False},
#  {'x': 557, 'y': False},
#  {'x': 558, 'y': False},
#  {'x': 559, 'y': False},
#  {'x': 560, 'y': False},
#  {'x': 561, 'y': False},
#  {'x': 562, 'y': False},
#  {'x': 563, 'y': False},
#  {'x': 564, 'y': False},
#  {'x': 565, 'y': False},
#  {'x': 566, 'y': False},
#  {'x': 567, 'y': False},
#  {'x': 568, 'y': False},
#  {'x': 569, 'y': False},
#  {'x': 570, 'y': False},
#  {'x': 571, 'y': False},
#  {'x': 572, 'y': False},
#  {'x': 573, 'y': False},
#  {'x': 574, 'y': False},
#  {'x': 575, 'y': False},
#  {'x': 576, 'y': False},
#  {'x': 577, 'y': False},
#  {'x': 578, 'y': False},
#  {'x': 579, 'y': False},
#  {'x': 580, 'y': False},
#  {'x': 581, 'y': False},
#  {'x': 582, 'y': False},
#  {'x': 583, 'y': False},
#  {'x': 584, 'y': False},
#  {'x': 585, 'y': False},
#  {'x': 586, 'y': False},
#  {'x': 587, 'y': False},
#  {'x': 588, 'y': False},
#  {'x': 589, 'y': False},
#  {'x': 590, 'y': False},
#  {'x': 591, 'y': False},
#  {'x': 592, 'y': False},
#  {'x': 593, 'y': False},
#  {'x': 594, 'y': False},
#  {'x': 595, 'y': False},
#  {'x': 596, 'y': False},
#  {'x': 597, 'y': False},
#  {'x': 598, 'y': False},
#  {'x': 599, 'y': False},
#  {'x': 600, 'y': False},
#  {'x': 601, 'y': False},
#  {'x': 602, 'y': False},
#  {'x': 603, 'y': False},
#  {'x': 604, 'y': 8.950000000000001},
#  {'x': 605, 'y': 9.200000000000001},
#  {'x': 606, 'y': 9.450000000000001},
#  {'x': 607, 'y': 9.700000000000001},
#  {'x': 608, 'y': 9.950000000000001},
#  {'x': 609, 'y': 10.200000000000001},
#  {'x': 610, 'y': 10.450000000000001},
#  {'x': 611, 'y': 10.700000000000001},
#  {'x': 612, 'y': 10.950000000000001},
#  {'x': 613, 'y': 10.8},
#  {'x': 614, 'y': 10.65},
#  {'x': 615, 'y': 10.5},
#  {'x': 616, 'y': 10.350000000000001},
#  {'x': 617, 'y': 10.200000000000001},
#  {'x': 618, 'y': 10.05},
#  {'x': 619, 'y': 15.0},
#  {'x': 620, 'y': 14.85},
#  {'x': 621, 'y': 14.700000000000001},
#  {'x': 622, 'y': False},
#  {'x': 623, 'y': False},
#  {'x': 624, 'y': False},
#  {'x': 625, 'y': False},
#  {'x': 626, 'y': False},
#  {'x': 627, 'y': False},
#  {'x': 628, 'y': False},
#  {'x': 629, 'y': False},
#  {'x': 630, 'y': False},
#  {'x': 631, 'y': False},
#  {'x': 632, 'y': False},
#  {'x': 633, 'y': False},
#  {'x': 634, 'y': False},
#  {'x': 635, 'y': False},
#  {'x': 636, 'y': False},
#  {'x': 637, 'y': False},
#  {'x': 638, 'y': False},
#  {'x': 639, 'y': False},
#  {'x': 640, 'y': False},
#  {'x': 641, 'y': False},
#  {'x': 642, 'y': False},
#  {'x': 643, 'y': False},
#  {'x': 644, 'y': False},
#  {'x': 645, 'y': False},
#  {'x': 646, 'y': False},
#  {'x': 647, 'y': False},
#  {'x': 648, 'y': False},
#  {'x': 649, 'y': False},
#  {'x': 650, 'y': False},
#  {'x': 651, 'y': False},
#  {'x': 652, 'y': False},
#  {'x': 653, 'y': False},
#  {'x': 654, 'y': False},
#  {'x': 655, 'y': False},
#  {'x': 656, 'y': False},
#  {'x': 657, 'y': False},
#  {'x': 658, 'y': False},
#  {'x': 659, 'y': False},
#  {'x': 660, 'y': False},
#  {'x': 661, 'y': False},
#  {'x': 662, 'y': False},
#  {'x': 663, 'y': False},
#  {'x': 664, 'y': False},
#  {'x': 665, 'y': False},
#  {'x': 666, 'y': False},
#  {'x': 667, 'y': False},
#  {'x': 668, 'y': False},
#  {'x': 669, 'y': False},
#  {'x': 670, 'y': False},
#  {'x': 671, 'y': False},
#  {'x': 672, 'y': False},
#  {'x': 673, 'y': False},
#  {'x': 674, 'y': False},
#  {'x': 675, 'y': False},
#  {'x': 676, 'y': False},
#  {'x': 677, 'y': False},
#  {'x': 678, 'y': False},
#  {'x': 679, 'y': False},
#  {'x': 680, 'y': False},
#  {'x': 681, 'y': False},
#  {'x': 682, 'y': False},
#  {'x': 683, 'y': False},
#  {'x': 684, 'y': False},
#  {'x': 685, 'y': False},
#  {'x': 686, 'y': False},
#  {'x': 687, 'y': False},
#  {'x': 688, 'y': False},
#  {'x': 689, 'y': False},
#  {'x': 690, 'y': False},
#  {'x': 691, 'y': False},
#  {'x': 692, 'y': False},
#  {'x': 693, 'y': False},
#  {'x': 694, 'y': False},
#  {'x': 695, 'y': False},
#  {'x': 696, 'y': False},
#  {'x': 697, 'y': False},
#  {'x': 698, 'y': False},
#  {'x': 699, 'y': False},
#  {'x': 700, 'y': False},
#  {'x': 701, 'y': False},
#  {'x': 702, 'y': False},
#  {'x': 703, 'y': False},
#  {'x': 704, 'y': False},
#  {'x': 705, 'y': False},
#  {'x': 706, 'y': False},
#  {'x': 707, 'y': False},
#  {'x': 708, 'y': False},
#  {'x': 709, 'y': False},
#  {'x': 710, 'y': False},
#  {'x': 711, 'y': False},
#  {'x': 712, 'y': False},
#  {'x': 713, 'y': False},
#  {'x': 714, 'y': False},
#  {'x': 715, 'y': False},
#  {'x': 716, 'y': False},
#  {'x': 717, 'y': False},
#  {'x': 718, 'y': False},
#  {'x': 719, 'y': False},
#  {'x': 720, 'y': False},
#  {'x': 721, 'y': False},
#  {'x': 722, 'y': False},
#  {'x': 723, 'y': False},
#  {'x': 724, 'y': False},
#  {'x': 725, 'y': False},
#  {'x': 726, 'y': False},
#  {'x': 727, 'y': False},
#  {'x': 728, 'y': False},
#  {'x': 729, 'y': False},
#  {'x': 730, 'y': False},
#  {'x': 731, 'y': False},
#  {'x': 732, 'y': False},
#  {'x': 733, 'y': False},
#  {'x': 734, 'y': False},
#  {'x': 735, 'y': False},
#  {'x': 736, 'y': False},
#  {'x': 737, 'y': False},
#  {'x': 738, 'y': False},
#  {'x': 739, 'y': False},
#  {'x': 740, 'y': False},
#  {'x': 741, 'y': False},
#  {'x': 742, 'y': False},
#  {'x': 743, 'y': False},
#  {'x': 744, 'y': False},
#  {'x': 745, 'y': False},
#  {'x': 746, 'y': False},
#  {'x': 747, 'y': False},
#  {'x': 748, 'y': False},
#  {'x': 749, 'y': False},
#  {'x': 750, 'y': False},
#  {'x': 751, 'y': 9.35},
#  {'x': 752, 'y': 9.6},
#  {'x': 753, 'y': 9.85},
#  {'x': 754, 'y': 10.1},
#  {'x': 755, 'y': 10.35},
#  {'x': 756, 'y': 10.6},
#  {'x': 757, 'y': 10.85},
#  {'x': 758, 'y': 11.1},
#  {'x': 759, 'y': 11.35},
#  {'x': 760, 'y': 11.6},
#  {'x': 761, 'y': 11.45},
#  {'x': 762, 'y': 11.299999999999999},
#  {'x': 763, 'y': 11.15},
#  {'x': 764, 'y': 11.0},
#  {'x': 765, 'y': 10.85},
#  {'x': 766, 'y': 10.7},
#  {'x': 767, 'y': 10.549999999999999},
#  {'x': 768, 'y': 10.4},
#  {'x': 769, 'y': 10.25},
#  {'x': 770, 'y': 10.1},
#  {'x': 771, 'y': False},
#  {'x': 772, 'y': False},
#  {'x': 773, 'y': False},
#  {'x': 774, 'y': False},
#  {'x': 775, 'y': False},
#  {'x': 776, 'y': False},
#  {'x': 777, 'y': False},
#  {'x': 778, 'y': False},
#  {'x': 779, 'y': False},
#  {'x': 780, 'y': False},
#  {'x': 781, 'y': False},
#  {'x': 782, 'y': False},
#  {'x': 783, 'y': False},
#  {'x': 784, 'y': False},
#  {'x': 785, 'y': False},
#  {'x': 786, 'y': False},
#  {'x': 787, 'y': False},
#  {'x': 788, 'y': False},
#  {'x': 789, 'y': False},
#  {'x': 790, 'y': False},
#  {'x': 791, 'y': False},
#  {'x': 792, 'y': False},
#  {'x': 793, 'y': False},
#  {'x': 794, 'y': False},
#  {'x': 795, 'y': False},
#  {'x': 796, 'y': False},
#  {'x': 797, 'y': False},
#  {'x': 798, 'y': False},
#  {'x': 799, 'y': False},
#  {'x': 800, 'y': False},
#  {'x': 801, 'y': False},
#  {'x': 802, 'y': False},
#  {'x': 803, 'y': False},
#  {'x': 804, 'y': False},
#  {'x': 805, 'y': False},
#  {'x': 806, 'y': False},
#  {'x': 807, 'y': False},
#  {'x': 808, 'y': False},
#  {'x': 809, 'y': False},
#  {'x': 810, 'y': False},
#  {'x': 811, 'y': False},
#  {'x': 812, 'y': False},
#  {'x': 813, 'y': False},
#  {'x': 814, 'y': False},
#  {'x': 815, 'y': False},
#  {'x': 816, 'y': False},
#  {'x': 817, 'y': False},
#  {'x': 818, 'y': False},
#  {'x': 819, 'y': False},
#  {'x': 820, 'y': False},
#  {'x': 821, 'y': False},
#  {'x': 822, 'y': False},
#  {'x': 823, 'y': False},
#  {'x': 824, 'y': False},
#  {'x': 825, 'y': False},
#  {'x': 826, 'y': False},
#  {'x': 827, 'y': False},
#  {'x': 828, 'y': False},
#  {'x': 829, 'y': False},
#  {'x': 830, 'y': False},
#  {'x': 831, 'y': False},
#  {'x': 832, 'y': False},
#  {'x': 833, 'y': False},
#  {'x': 834, 'y': False},
#  {'x': 835, 'y': False},
#  {'x': 836, 'y': False},
#  {'x': 837, 'y': False},
#  {'x': 838, 'y': False},
#  {'x': 839, 'y': False},
#  {'x': 840, 'y': False},
#  {'x': 841, 'y': False},
#  {'x': 842, 'y': False},
#  {'x': 843, 'y': False},
#  {'x': 844, 'y': False},
#  {'x': 845, 'y': False},
#  {'x': 846, 'y': False},
#  {'x': 847, 'y': False},
#  {'x': 848, 'y': False},
#  {'x': 849, 'y': False},
#  {'x': 850, 'y': False},
#  {'x': 851, 'y': False},
#  {'x': 852, 'y': False},
#  {'x': 853, 'y': False},
#  {'x': 854, 'y': False},
#  {'x': 855, 'y': False},
#  {'x': 856, 'y': False},
#  {'x': 857, 'y': False},
#  {'x': 858, 'y': False},
#  {'x': 859, 'y': False},
#  {'x': 860, 'y': False},
#  {'x': 861, 'y': False},
#  {'x': 862, 'y': False},
#  {'x': 863, 'y': False},
#  {'x': 864, 'y': False},
#  {'x': 865, 'y': False},
#  {'x': 866, 'y': False},
#  {'x': 867, 'y': False},
#  {'x': 868, 'y': False},
#  {'x': 869, 'y': False},
#  {'x': 870, 'y': False},
#  {'x': 871, 'y': False},
#  {'x': 872, 'y': False},
#  {'x': 873, 'y': False},
#  {'x': 874, 'y': False},
#  {'x': 875, 'y': False},
#  {'x': 876, 'y': False},
#  {'x': 877, 'y': False},
#  {'x': 878, 'y': False},
#  {'x': 879, 'y': False},
#  {'x': 880, 'y': False},
#  {'x': 881, 'y': False},
#  {'x': 882, 'y': False},
#  {'x': 883, 'y': False},
#  {'x': 884, 'y': False},
#  {'x': 885, 'y': False},
#  {'x': 886, 'y': False},
#  {'x': 887, 'y': False},
#  {'x': 888, 'y': False},
#  {'x': 889, 'y': False},
#  {'x': 890, 'y': False},
#  {'x': 891, 'y': False},
#  {'x': 892, 'y': False},
#  {'x': 893, 'y': False},
#  {'x': 894, 'y': False},
#  {'x': 895, 'y': False},
#  {'x': 896, 'y': False},
#  {'x': 897, 'y': False},
#  {'x': 898, 'y': False},
#  {'x': 899, 'y': False},
#  {'x': 900, 'y': False},
#  {'x': 901, 'y': False},
#  {'x': 902, 'y': False},
#  {'x': 903, 'y': False},
#  {'x': 904, 'y': False},
#  {'x': 905, 'y': False},
#  {'x': 906, 'y': False},
#  {'x': 907, 'y': False},
#  {'x': 908, 'y': False},
#  {'x': 909, 'y': False},
#  {'x': 910, 'y': False},
#  {'x': 911, 'y': False},
#  {'x': 912, 'y': False},
#  {'x': 913, 'y': False},
#  {'x': 914, 'y': 9.75},
#  {'x': 915, 'y': 10.0},
#  {'x': 916, 'y': 10.25},
#  {'x': 917, 'y': 10.5},
#  {'x': 918, 'y': 10.75},
#  {'x': 919, 'y': 11.0},
#  {'x': 920, 'y': 11.25},
#  {'x': 921, 'y': 11.5},
#  {'x': 922, 'y': 11.75},
#  {'x': 923, 'y': 12.0},
#  {'x': 924, 'y': 12.25},
#  {'x': 925, 'y': 12.1},
#  {'x': 926, 'y': 11.950000000000001},
#  {'x': 927, 'y': 11.799999999999999},
#  {'x': 928, 'y': 11.65},
#  {'x': 929, 'y': 11.5},
#  {'x': 930, 'y': 11.35},
#  {'x': 931, 'y': 11.200000000000001},
#  {'x': 932, 'y': 11.049999999999999},
#  {'x': 933, 'y': 10.9},
#  {'x': 934, 'y': 10.75},
#  {'x': 935, 'y': 10.6},
#  {'x': 936, 'y': False},
#  {'x': 937, 'y': False},
#  {'x': 938, 'y': False},
#  {'x': 939, 'y': False},
#  {'x': 940, 'y': False},
#  {'x': 941, 'y': False},
#  {'x': 942, 'y': False},
#  {'x': 943, 'y': False},
#  {'x': 944, 'y': False},
#  {'x': 945, 'y': False},
#  {'x': 946, 'y': False},
#  {'x': 947, 'y': False},
#  {'x': 948, 'y': False},
#  {'x': 949, 'y': False},
#  {'x': 950, 'y': False},
#  {'x': 951, 'y': False},
#  {'x': 952, 'y': False},
#  {'x': 953, 'y': False},
#  {'x': 954, 'y': False},
#  {'x': 955, 'y': False},
#  {'x': 956, 'y': False},
#  {'x': 957, 'y': False},
#  {'x': 958, 'y': False},
#  {'x': 959, 'y': False},
#  {'x': 960, 'y': False},
#  {'x': 961, 'y': False},
#  {'x': 962, 'y': False},
#  {'x': 963, 'y': False},
#  {'x': 964, 'y': False},
#  {'x': 965, 'y': False},
#  {'x': 966, 'y': False},
#  {'x': 967, 'y': False},
#  {'x': 968, 'y': False},
#  {'x': 969, 'y': False},
#  {'x': 970, 'y': False},
#  {'x': 971, 'y': False},
#  {'x': 972, 'y': False},
#  {'x': 973, 'y': False},
#  {'x': 974, 'y': False},
#  {'x': 975, 'y': False},
#  {'x': 976, 'y': False},
#  {'x': 977, 'y': False},
#  {'x': 978, 'y': False},
#  {'x': 979, 'y': False},
#  {'x': 980, 'y': False},
#  {'x': 981, 'y': False},
#  {'x': 982, 'y': False},
#  {'x': 983, 'y': False},
#  {'x': 984, 'y': False},
#  {'x': 985, 'y': False},
#  {'x': 986, 'y': False},
#  {'x': 987, 'y': False},
#  {'x': 988, 'y': False},
#  {'x': 989, 'y': False},
#  {'x': 990, 'y': False},
#  {'x': 991, 'y': False},
#  {'x': 992, 'y': False},
#  {'x': 993, 'y': False},
#  {'x': 994, 'y': False},
#  {'x': 995, 'y': False},
#  {'x': 996, 'y': False},
#  {'x': 997, 'y': False},
#  {'x': 998, 'y': False},
#  {'x': 999, 'y': False},
#  ...]

# %%
best = gradient_descent(pds, constraints, DEFAULTS, x_0s = spiral[0], print_workings=True)
# Out:
# --------------------------------------------------------------------------------------------
# Iteration	X	g	diff
# Start (0)	{'x1': 0, 'x4': 0, 'x3': 0, 'x2': 0}	{'x1': 3, 'x4': 1, 'x3': 4, 'x2': 5}	N/A
# 1		{'x1': 0.3, 'x2': 0.5, 'x3': 0.4, 'x4': 0.1}	{'x1': 3, 'x2': 5, 'x3': 4, 'x4': 1}	0.714
# 2		{'x1': 0.6, 'x4': 0.2, 'x3': 0.8, 'x2': 1.0}	{'x1': 3, 'x4': 1, 'x3': 4, 'x2': 5}	0.714
# 3		{'x1': 0.9, 'x2': 1.5, 'x3': 1.2, 'x4': 0.3}	{'x1': 3, 'x2': 5, 'x3': 4, 'x4': 1}	0.714
# 4		{'x1': 1.2, 'x4': 0.4, 'x3': 1.6, 'x2': 2.0}	{'x1': 3, 'x4': 1, 'x3': 4, 'x2': 5}	0.714

# %%
print_all_constraints(best[1], constraints)
print("Profit: ", f(best[1]))
# Out:
# x1 not -ve constraint: 0 <= 0.9
# x2 not -ve constraint: 0 <= 1.5
# x3 not -ve constraint: 0 <= 1.2
# x4 not -ve constraint: 0 <= 0.3
# green constraint: 5.4 <= 10
# red constraint: 6.0 <= 6
# blue constraint: 4.2 <= 10
# yellow constraint: 6.9 <= 18
# brown constraint: 2.1 <= 8
# purple constraint: 4.5 <= 12
# Profit:  15.3
