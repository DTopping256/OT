# %%
import random
import math
import sys

# Allows me to import my modules
sys.path.extend(["../../modules", "../"])

e = math.e

# %%
from problem import f, constraints, check_all_constraints, print_all_constraints

# %%
class SA_defaults:
    def __init__(self, is_maximisation=False, s_0=None, t_0=None, neighbourhood_func=None, step_size=None, temp_reduc_func=None, acc_prob_func=None, stop_cond=None, max_i=None, max_epoch=None, tolerance=None):
        self.is_maximisation = is_maximisation
        self.s_0 = s_0
        self.t_0 = t_0
        self.neighbourhood_func = neighbourhood_func
        self.step_size = step_size
        self.temp_reduc_func = temp_reduc_func
        self.acc_prob_func = acc_prob_func
        self.stop_cond = stop_cond
        self.max_i = max_i
        self.max_epoch = max_epoch
        self.tolerance = tolerance

def simulated_annealing(f, DEFAULTS, is_maximisation=None, s_0=None, t_0=None, neighbourhood_func=None, step_size=None, temp_reduc_func=None, acc_prob_func=None, stop_cond=None, max_i=None, max_epoch=None, tolerance=None, print_workings=False):
    # Default parameters
    is_maximisation = DEFAULTS.is_maximisation if is_maximisation is None else is_maximisation
    s_0 = DEFAULTS.s_0 if s_0 is None else s_0
    t_0 = DEFAULTS.t_0 if t_0 is None else t_0
    neighbourhood_func = DEFAULTS.neighbourhood_func if neighbourhood_func is None else neighbourhood_func
    step_size = DEFAULTS.step_size if step_size is None else step_size
    temp_reduc_func = DEFAULTS.temp_reduc_func if temp_reduc_func is None else temp_reduc_func
    acc_prob_func = DEFAULTS.acc_prob_func if acc_prob_func is None else acc_prob_func
    stop_cond = DEFAULTS.stop_cond if stop_cond is None else stop_cond
    max_i = DEFAULTS.max_i if max_i is None else max_i
    max_epoch = DEFAULTS.max_epoch if max_epoch is None else max_epoch
    tolerance = DEFAULTS.tolerance if tolerance is None else tolerance
    
    # Sets the initial value of s_n (when n = 0)
    solution = {k: v for k, v in s_0.items()}
    # Sets the initial value of s_n-1 (not used for the first iteration of the outer loop)
    prev_solution = {k: v for k, v in s_0.items()}
    # The current temperature
    temperature = t_0
    
    # The iterations of the outer (while) loop.
    iteration_counter = 0
    step_array = []
    while (iteration_counter == 0 or not stop_cond(iteration_counter, max_i, solution, prev_solution, tolerance)):
        if (not check_all_constraints(solution, constraints, print_workings)): 
            if (iteration_counter > 0):
                solution = {k: v for k, v in step_array[-1][0].items()}
                temperature = step_array[-1][1]
                step_array = step_array[:-1]
            if (iteration_counter == 0):
                solution = False
            break
        if (print_workings == True):
            print("--------------------------------------------------------------------------------------------\ns_{}: {}".format(iteration_counter, {k: round(v, 3) for k, v in solution.items()}))
        prev_solution = {k: v for k, v in solution.items()}
        step_array.append((prev_solution, temperature))
        for epoch in range(1, max_epoch+1):
            neighbourhood = neighbourhood_func(solution, step_size)
            possible_solution = neighbourhood[random.randrange(
                0, len(neighbourhood))]
            solution_eval_diff = f(possible_solution) - f(solution)
            # If the difference between the possible solution (solution picked in the current epoch) and the solution (the solution of the current iteration of epochs) when put through the acceptance probablity function, is greater than random noise then pick it.
            accepted = solution_eval_diff > 0 if is_maximisation else solution_eval_diff < 0 
            if (accepted or acc_prob_func(
                    solution_eval_diff, temperature) > random.random()):
                # Set a new value of solution
                solution = {k: v for k, v in possible_solution.items()}
                accepted = True
            if (print_workings == True):
                print("Epoch: {}\ts: {}    \tt: {}\tAccepted: {}\tDiff: {}".format(epoch, {k: round(v, 3) for k, v in possible_solution.items()}, round(temperature, 3), accepted, round(solution_eval_diff, 3)))
        # Reduce the temperature and increment the iteration counter
        temperature = temp_reduc_func(temperature)
        iteration_counter += 1
    if (iteration_counter > 0):
        step_array.append(({k: v for k, v in solution.items()}, temperature))
    return (step_array, solution)

# %%
s_0 = {"x1": 0, "x2": 0, "x3": 0, "x4": 0}
t_0 = 5.0
step_size = 0.1
max_i = 50
max_epoch = 8
tolerance = 0.1

# ±x1 or ±x2 or ±x3 or ±x4
def neighbourhood_func(s, step_size):
    neighbourhood = []
    keys = s.keys()
    for i in range(len(keys)*2):
        sign = 1 if i < 4 else -1
        key = list(keys)[i % 4]
        neighbour = {k: v for k, v in s.items()}
        neighbour[key] += sign*step_size
        neighbourhood.append(neighbour)
    return neighbourhood

def temp_reduc_func(x):
    return float(0.75*x)

def acc_prob_func(diff, temperature):
    return float(e**(-abs(diff)/temperature))

def stop_cond(iteration_counter=None, max_i=None, solution=None, prev_solution=None, tolerance=None):
    if (iteration_counter > 0):
        if (iteration_counter >= max_i):
            return True
    return False

DEFAULTS = SA_defaults(True, s_0, t_0, neighbourhood_func, step_size, temp_reduc_func, acc_prob_func, stop_cond, max_i, max_epoch, tolerance)

# %%
results = simulated_annealing(f, DEFAULTS, print_workings=True)
results[1]
# Out:
# --------------------------------------------------------------------------------------------
# s_0: {'x2': 0, 'x4': 0, 'x1': 0, 'x3': 0}
# Epoch: 1	s: {'x2': -0.1, 'x4': 0, 'x1': 0, 'x3': 0}    	t: 5.0	Accepted: True	Diff: -0.5
# Epoch: 2	s: {'x2': -0.1, 'x4': 0, 'x1': -0.1, 'x3': 0}    	t: 5.0	Accepted: True	Diff: -0.3
# Epoch: 3	s: {'x2': 0.0, 'x4': 0, 'x1': -0.1, 'x3': 0}    	t: 5.0	Accepted: True	Diff: 0.5
# Epoch: 4	s: {'x2': 0.0, 'x4': 0, 'x1': -0.2, 'x3': 0}    	t: 5.0	Accepted: True	Diff: -0.3
# Epoch: 5	s: {'x2': 0.0, 'x4': 0.1, 'x1': -0.2, 'x3': 0}    	t: 5.0	Accepted: True	Diff: 0.1
# Epoch: 6	s: {'x2': 0.0, 'x4': 0.1, 'x1': -0.2, 'x3': -0.1}    	t: 5.0	Accepted: True	Diff: -0.4
# Epoch: 7	s: {'x2': 0.1, 'x4': 0.1, 'x1': -0.2, 'x3': -0.1}    	t: 5.0	Accepted: True	Diff: 0.5
# Epoch: 8	s: {'x2': 0.1, 'x4': 0.1, 'x1': -0.2, 'x3': -0.2}    	t: 5.0	Accepted: True	Diff: -0.4
# (x1 not -ve constraint fails)
# {'x1': 0, 'x2': 0, 'x3': 0, 'x4': 0}

# %%
print_all_constraints(results[1], constraints)
print("Profit: ", f(results[1]))
# Out:
# x1 not -ve constraint: 0 <= 0
# x2 not -ve constraint: 0 <= 0
# x3 not -ve constraint: 0 <= 0
# x4 not -ve constraint: 0 <= 0
# green constraint: 0 <= 10
# red constraint: 0 <= 6
# blue constraint: 0 <= 10
# yellow constraint: 0 <= 18
# brown constraint: 0 <= 8
# purple constraint: 0 <= 12
# Profit:  0

# %%
# Imports my plotting module
import batch_plotting as batch_plt

# Imports my spiral coordinate generating module
from utilities import n_dim_spiral

# %%
# Batch testing start position
starting_point_results = []
end_point = []
spiral = n_dim_spiral({"x1": 0, "x2": 0, "x3": 0, "x4": 0}, 1000, 0.1)
for i in range(20):
    for j in range(len(spiral)):
        ps = spiral[j]
        result = simulated_annealing(f, DEFAULTS, s_0 = ps)
        end_point.append(result[1])
        starting_point_results.append({"x": j, "y": f(result[1]) if result[1] is not False else False})

# %%
batch_plt.plot_2d_batch_accuracy("profit: f(s_n)", "starting point: s_0", False, starting_point_results)

# %%
# Extract the results above 16 profit

best_sprs = [(i, list(filter(lambda e: e["y"] > 16, starting_point_results[i*1000: (i+1)*1000]))) for i in range(20)]
best_sprs = list(filter(lambda e: len(e[1]) > 0, best_sprs))
best_sprs
# Out:
# [(2,
#   [{'x': 22, 'y': 17.700000000000003},
#    {'x': 63, 'y': 16.400000000000002},
#    {'x': 260, 'y': 17.100000000000005}]),
#  (6,
#   [{'x': 0, 'y': 16.1},
#    {'x': 23, 'y': 16.900000000000002},
#    {'x': 481, 'y': 16.1}]),
#  (9, [{'x': 177, 'y': 17.600000000000005}]),
#  (11, [{'x': 61, 'y': 16.300000000000004}]),
#  (12, [{'x': 24, 'y': 17.200000000000003}]),
#  (14, [{'x': 478, 'y': 16.700000000000003}]),
#  (16, [{'x': 359, 'y': 16.700000000000003}]),
#  (18, [{'x': 58, 'y': 16.400000000000002}]),
#  (19, [{'x': 610, 'y': 16.300000000000004}])]

# %%
best_start_sprs = []
for t in best_sprs:
    for ele in t[1]:
        keys = ["x1", "x2", "x3", "x4"]
        x = ele["x"]
        y = ele["y"]
        start_cx = spiral[x]
        end_cx = end_point[x+t[0]*1000]
        if end_cx is not False:
            best_start_sprs.append(start_cx)
            print("{} {} | {} | {}".format(x, [round(start_cx[key],3) for key in keys], [round(end_cx[key],3) for key in keys], round(y, 3)))
# Out:
# 63 [0.3, 0.0, 0.3, 0.3] | [1.1, 0.7, 1.2, 0.4] | 16.4
# 481 [0.8, 0.7, 0.8, 0.8] | [1.5, 0.8, 0.5, 0.6] | 16.1

# %%
# Finding the average best start point indicated by the batch test
avg = {"x1": 0, "x2": 0, "x3": 0, "x4": 0}
dims = 4
for i in best_start_sprs:
    for k, v in i.items():
        avg[k] += v
for k, v in avg.items():
    avg[k] = round(avg[k]/len(best_start_sprs), 3)
print("Best starting point on average: ", avg, "\n (will vary each time batch test run)")
# Out:
# Best starting point on average:  {'x2': 0.35, 'x4': 0.55, 'x1': 0.55, 'x3': 0.55}
#  (will vary each time batch test run)

# %%
# Testing certain 'end_points'
print_all_constraints(end_point[4372], constraints)
print("Profit: ", f(end_point[4372]))
# Out:
# x1 not -ve constraint: 0 <= 1.6000000000000003
# x2 not -ve constraint: 0 <= 0.7999999999999999
# x3 not -ve constraint: 0 <= 0.6
# x4 not -ve constraint: 0 <= 0.4
# green constraint: 4.2 <= 10
# red constraint: 5.6 <= 6
# blue constraint: 5.6 <= 10
# yellow constraint: 4.8 <= 18
# brown constraint: 1.8 <= 8
# purple constraint: 3.0 <= 12
# Profit:  11.600000000000001

# %%
# Set my start point to (0.7, 0.7, 0.7, 0.7) which was the best the first time I ran the starting point batch test
DEFAULTS.s_0 = {"x1": 0.7, "x2": 0.7, "x3": 0.7, "x4": 0.7}

# Batch testing starting temperature and temperature function
temp_results = []
end_point = []

for g in range(40):
    grad = (1+g)/41
    linear_temp_func = lambda x: x*grad
    for t in range(30):
        start_temp = (t+1)*0.2
        for i in range(10):
            result = simulated_annealing(f, DEFAULTS, t_0=start_temp, temp_reduc_func=linear_temp_func)
            end_point.append(result[1])
            temp_results.append({"x": grad, "y": start_temp, "z": f(result[1]) if result[1] is not False else False})

# %%
batch_plt.plot_3d_batch_accuracy("temperature gradient", "start temperature: t_0", "profit: f(s_n)", False, temp_results)

# %%
DEFAULTS.t_0 = 2
DEFAULTS.temp_reduc_func = lambda x: 0.9*x

# Batch testing step_size and max_epoch
step_epoch_results = []
end_point= []

for e in range(5, 31):
    for s in range(30):
        step_size = (s+1)/40
        for i in range(10):
            result = simulated_annealing(f, DEFAULTS, max_epoch=e, step_size=step_size)
            end_point.append(result[1])
            step_epoch_results.append({"x": step_size, "y": e, "z": f(result[1]) if result[1] is not False else False})

# %%
batch_plt.plot_3d_batch_accuracy("step size", "epochs", "profit: f(s_n)", False, step_epoch_results)

# %%
DEFAULTS.max_epoch = 10
DEFAULTS.step_size = 0.1

# Run through with improved parameters
results = simulated_annealing(f, DEFAULTS, print_workings=True)
print("\nStats:")
print_all_constraints(results[1], constraints)
print("\nProfit: {}\nSolution: {}".format(f(results[1]), [round(results[1][key], 3) for key in ["x1", "x2", "x3", "x4"]]))
# Out:
# --------------------------------------------------------------------------------------------
# s_0: {'x2': 0.7, 'x4': 0.7, 'x1': 0.7, 'x3': 0.7}
# Epoch: 1	s: {'x2': 0.7, 'x4': 0.7, 'x1': 0.8, 'x3': 0.7}    	t: 2	Accepted: True	Diff: 0.3
# Epoch: 2	s: {'x2': 0.6, 'x4': 0.7, 'x1': 0.8, 'x3': 0.7}    	t: 2	Accepted: False	Diff: -0.5
# Epoch: 3	s: {'x2': 0.7, 'x4': 0.7, 'x1': 0.7, 'x3': 0.7}    	t: 2	Accepted: True	Diff: -0.3
# Epoch: 4	s: {'x2': 0.7, 'x4': 0.7, 'x1': 0.7, 'x3': 0.6}    	t: 2	Accepted: False	Diff: -0.4
# Epoch: 5	s: {'x2': 0.7, 'x4': 0.7, 'x1': 0.8, 'x3': 0.7}    	t: 2	Accepted: True	Diff: 0.3
# Epoch: 6	s: {'x2': 0.7, 'x4': 0.8, 'x1': 0.8, 'x3': 0.7}    	t: 2	Accepted: True	Diff: 0.1
# Epoch: 7	s: {'x2': 0.7, 'x4': 0.8, 'x1': 0.8, 'x3': 0.6}    	t: 2	Accepted: False	Diff: -0.4
# Epoch: 8	s: {'x2': 0.7, 'x4': 0.8, 'x1': 0.7, 'x3': 0.7}    	t: 2	Accepted: True	Diff: -0.3
# Epoch: 9	s: {'x2': 0.7, 'x4': 0.8, 'x1': 0.7, 'x3': 0.6}    	t: 2	Accepted: False	Diff: -0.4
# Epoch: 10	s: {'x2': 0.7, 'x4': 0.7, 'x1': 0.7, 'x3': 0.7}    	t: 2	Accepted: True	Diff: -0.1
# --------------------------------------------------------------------------------------------
# s_1: {'x2': 0.7, 'x4': 0.7, 'x1': 0.7, 'x3': 0.7}
# Epoch: 1	s: {'x2': 0.8, 'x4': 0.7, 'x1': 0.7, 'x3': 0.7}    	t: 1.8	Accepted: True	Diff: 0.5
# Epoch: 2	s: {'x2': 0.9, 'x4': 0.7, 'x1': 0.7, 'x3': 0.7}    	t: 1.8	Accepted: True	Diff: 0.5
# Epoch: 3	s: {'x2': 0.9, 'x4': 0.6, 'x1': 0.7, 'x3': 0.7}    	t: 1.8	Accepted: True	Diff: -0.1
# Epoch: 4	s: {'x2': 0.9, 'x4': 0.5, 'x1': 0.7, 'x3': 0.7}    	t: 1.8	Accepted: True	Diff: -0.1
# Epoch: 5	s: {'x2': 1.0, 'x4': 0.5, 'x1': 0.7, 'x3': 0.7}    	t: 1.8	Accepted: True	Diff: 0.5
# Epoch: 6	s: {'x2': 1.0, 'x4': 0.5, 'x1': 0.8, 'x3': 0.7}    	t: 1.8	Accepted: True	Diff: 0.3
# Epoch: 7	s: {'x2': 1.0, 'x4': 0.4, 'x1': 0.8, 'x3': 0.7}    	t: 1.8	Accepted: True	Diff: -0.1
# Epoch: 8	s: {'x2': 1.1, 'x4': 0.4, 'x1': 0.8, 'x3': 0.7}    	t: 1.8	Accepted: True	Diff: 0.5
# Epoch: 9	s: {'x2': 1.1, 'x4': 0.3, 'x1': 0.8, 'x3': 0.7}    	t: 1.8	Accepted: True	Diff: -0.1
# Epoch: 10	s: {'x2': 1.1, 'x4': 0.3, 'x1': 0.9, 'x3': 0.7}    	t: 1.8	Accepted: True	Diff: 0.3
# --------------------------------------------------------------------------------------------
# s_2: {'x2': 1.1, 'x4': 0.3, 'x1': 0.9, 'x3': 0.7}
# Epoch: 1	s: {'x2': 1.1, 'x4': 0.3, 'x1': 0.8, 'x3': 0.7}    	t: 1.62	Accepted: False	Diff: -0.3
# Epoch: 2	s: {'x2': 1.1, 'x4': 0.3, 'x1': 0.8, 'x3': 0.7}    	t: 1.62	Accepted: True	Diff: -0.3
# Epoch: 3	s: {'x2': 1.1, 'x4': 0.2, 'x1': 0.8, 'x3': 0.7}    	t: 1.62	Accepted: True	Diff: -0.1
# Epoch: 4	s: {'x2': 1.1, 'x4': 0.2, 'x1': 0.9, 'x3': 0.7}    	t: 1.62	Accepted: True	Diff: 0.3
# Epoch: 5	s: {'x2': 1.1, 'x4': 0.2, 'x1': 0.9, 'x3': 0.6}    	t: 1.62	Accepted: True	Diff: -0.4
# Epoch: 6	s: {'x2': 1.1, 'x4': 0.2, 'x1': 0.9, 'x3': 0.5}    	t: 1.62	Accepted: False	Diff: -0.4
# Epoch: 7	s: {'x2': 1.0, 'x4': 0.2, 'x1': 0.9, 'x3': 0.6}    	t: 1.62	Accepted: True	Diff: -0.5
# Epoch: 8	s: {'x2': 1.0, 'x4': 0.2, 'x1': 0.9, 'x3': 0.7}    	t: 1.62	Accepted: True	Diff: 0.4
# Epoch: 9	s: {'x2': 1.0, 'x4': 0.2, 'x1': 0.8, 'x3': 0.7}    	t: 1.62	Accepted: False	Diff: -0.3
# Epoch: 10	s: {'x2': 1.0, 'x4': 0.3, 'x1': 0.9, 'x3': 0.7}    	t: 1.62	Accepted: True	Diff: 0.1
# --------------------------------------------------------------------------------------------
# s_3: {'x2': 1.0, 'x4': 0.3, 'x1': 0.9, 'x3': 0.7}
# Epoch: 1	s: {'x2': 1.0, 'x4': 0.4, 'x1': 0.9, 'x3': 0.7}    	t: 1.458	Accepted: True	Diff: 0.1
# Epoch: 2	s: {'x2': 1.1, 'x4': 0.4, 'x1': 0.9, 'x3': 0.7}    	t: 1.458	Accepted: True	Diff: 0.5
# Epoch: 3	s: {'x2': 1.2, 'x4': 0.4, 'x1': 0.9, 'x3': 0.7}    	t: 1.458	Accepted: True	Diff: 0.5
# Epoch: 4	s: {'x2': 1.3, 'x4': 0.4, 'x1': 0.9, 'x3': 0.7}    	t: 1.458	Accepted: True	Diff: 0.5
# Epoch: 5	s: {'x2': 1.3, 'x4': 0.4, 'x1': 0.8, 'x3': 0.7}    	t: 1.458	Accepted: False	Diff: -0.3
# Epoch: 6	s: {'x2': 1.4, 'x4': 0.4, 'x1': 0.9, 'x3': 0.7}    	t: 1.458	Accepted: True	Diff: 0.5
# Epoch: 7	s: {'x2': 1.3, 'x4': 0.4, 'x1': 0.9, 'x3': 0.7}    	t: 1.458	Accepted: False	Diff: -0.5
# Epoch: 8	s: {'x2': 1.3, 'x4': 0.4, 'x1': 0.9, 'x3': 0.7}    	t: 1.458	Accepted: True	Diff: -0.5
# Epoch: 9	s: {'x2': 1.4, 'x4': 0.4, 'x1': 0.9, 'x3': 0.7}    	t: 1.458	Accepted: True	Diff: 0.5
# Epoch: 10	s: {'x2': 1.4, 'x4': 0.4, 'x1': 1.0, 'x3': 0.7}    	t: 1.458	Accepted: True	Diff: 0.3
# --------------------------------------------------------------------------------------------
# s_4: {'x2': 1.4, 'x4': 0.4, 'x1': 1.0, 'x3': 0.7}
# Epoch: 1	s: {'x2': 1.4, 'x4': 0.3, 'x1': 1.0, 'x3': 0.7}    	t: 1.312	Accepted: False	Diff: -0.1
# Epoch: 2	s: {'x2': 1.4, 'x4': 0.5, 'x1': 1.0, 'x3': 0.7}    	t: 1.312	Accepted: True	Diff: 0.1
# Epoch: 3	s: {'x2': 1.4, 'x4': 0.5, 'x1': 1.0, 'x3': 0.8}    	t: 1.312	Accepted: True	Diff: 0.4
# Epoch: 4	s: {'x2': 1.4, 'x4': 0.5, 'x1': 0.9, 'x3': 0.8}    	t: 1.312	Accepted: True	Diff: -0.3
# Epoch: 5	s: {'x2': 1.5, 'x4': 0.5, 'x1': 0.9, 'x3': 0.8}    	t: 1.312	Accepted: True	Diff: 0.5
# Epoch: 6	s: {'x2': 1.5, 'x4': 0.4, 'x1': 0.9, 'x3': 0.8}    	t: 1.312	Accepted: True	Diff: -0.1
# Epoch: 7	s: {'x2': 1.6, 'x4': 0.4, 'x1': 0.9, 'x3': 0.8}    	t: 1.312	Accepted: True	Diff: 0.5
# Epoch: 8	s: {'x2': 1.6, 'x4': 0.5, 'x1': 0.9, 'x3': 0.8}    	t: 1.312	Accepted: True	Diff: 0.1
# Epoch: 9	s: {'x2': 1.6, 'x4': 0.5, 'x1': 0.8, 'x3': 0.8}    	t: 1.312	Accepted: True	Diff: -0.3
# Epoch: 10	s: {'x2': 1.6, 'x4': 0.5, 'x1': 0.7, 'x3': 0.8}    	t: 1.312	Accepted: True	Diff: -0.3
# --------------------------------------------------------------------------------------------
# s_5: {'x2': 1.6, 'x4': 0.5, 'x1': 0.7, 'x3': 0.8}
# Epoch: 1	s: {'x2': 1.6, 'x4': 0.6, 'x1': 0.7, 'x3': 0.8}    	t: 1.181	Accepted: True	Diff: 0.1
# Epoch: 2	s: {'x2': 1.6, 'x4': 0.5, 'x1': 0.7, 'x3': 0.8}    	t: 1.181	Accepted: True	Diff: -0.1
# Epoch: 3	s: {'x2': 1.6, 'x4': 0.5, 'x1': 0.7, 'x3': 0.9}    	t: 1.181	Accepted: True	Diff: 0.4
# Epoch: 4	s: {'x2': 1.6, 'x4': 0.5, 'x1': 0.7, 'x3': 0.8}    	t: 1.181	Accepted: True	Diff: -0.4
# Epoch: 5	s: {'x2': 1.6, 'x4': 0.5, 'x1': 0.6, 'x3': 0.8}    	t: 1.181	Accepted: False	Diff: -0.3
# Epoch: 6	s: {'x2': 1.6, 'x4': 0.5, 'x1': 0.7, 'x3': 0.9}    	t: 1.181	Accepted: True	Diff: 0.4
# Epoch: 7	s: {'x2': 1.6, 'x4': 0.6, 'x1': 0.7, 'x3': 0.9}    	t: 1.181	Accepted: True	Diff: 0.1
# Epoch: 8	s: {'x2': 1.5, 'x4': 0.6, 'x1': 0.7, 'x3': 0.9}    	t: 1.181	Accepted: False	Diff: -0.5
# Epoch: 9	s: {'x2': 1.6, 'x4': 0.5, 'x1': 0.7, 'x3': 0.9}    	t: 1.181	Accepted: True	Diff: -0.1
# Epoch: 10	s: {'x2': 1.6, 'x4': 0.5, 'x1': 0.7, 'x3': 0.8}    	t: 1.181	Accepted: False	Diff: -0.4
# --------------------------------------------------------------------------------------------
# s_6: {'x2': 1.6, 'x4': 0.5, 'x1': 0.7, 'x3': 0.9}
# Epoch: 1	s: {'x2': 1.6, 'x4': 0.5, 'x1': 0.8, 'x3': 0.9}    	t: 1.063	Accepted: True	Diff: 0.3
# Epoch: 2	s: {'x2': 1.6, 'x4': 0.5, 'x1': 0.8, 'x3': 0.8}    	t: 1.063	Accepted: True	Diff: -0.4
# Epoch: 3	s: {'x2': 1.6, 'x4': 0.6, 'x1': 0.8, 'x3': 0.8}    	t: 1.063	Accepted: True	Diff: 0.1
# Epoch: 4	s: {'x2': 1.6, 'x4': 0.7, 'x1': 0.8, 'x3': 0.8}    	t: 1.063	Accepted: True	Diff: 0.1
# Epoch: 5	s: {'x2': 1.6, 'x4': 0.7, 'x1': 0.7, 'x3': 0.8}    	t: 1.063	Accepted: True	Diff: -0.3
# Epoch: 6	s: {'x2': 1.5, 'x4': 0.7, 'x1': 0.7, 'x3': 0.8}    	t: 1.063	Accepted: False	Diff: -0.5
# Epoch: 7	s: {'x2': 1.6, 'x4': 0.7, 'x1': 0.7, 'x3': 0.7}    	t: 1.063	Accepted: False	Diff: -0.4
# Epoch: 8	s: {'x2': 1.6, 'x4': 0.7, 'x1': 0.7, 'x3': 0.9}    	t: 1.063	Accepted: True	Diff: 0.4
# Epoch: 9	s: {'x2': 1.6, 'x4': 0.7, 'x1': 0.7, 'x3': 0.8}    	t: 1.063	Accepted: False	Diff: -0.4
# Epoch: 10	s: {'x2': 1.6, 'x4': 0.7, 'x1': 0.6, 'x3': 0.9}    	t: 1.063	Accepted: False	Diff: -0.3
# --------------------------------------------------------------------------------------------
# s_7: {'x2': 1.6, 'x4': 0.7, 'x1': 0.7, 'x3': 0.9}
# Epoch: 1	s: {'x2': 1.6, 'x4': 0.8, 'x1': 0.7, 'x3': 0.9}    	t: 0.957	Accepted: True	Diff: 0.1
# Epoch: 2	s: {'x2': 1.6, 'x4': 0.8, 'x1': 0.7, 'x3': 0.8}    	t: 0.957	Accepted: False	Diff: -0.4
# Epoch: 3	s: {'x2': 1.6, 'x4': 0.8, 'x1': 0.6, 'x3': 0.9}    	t: 0.957	Accepted: True	Diff: -0.3
# Epoch: 4	s: {'x2': 1.6, 'x4': 0.8, 'x1': 0.6, 'x3': 1.0}    	t: 0.957	Accepted: True	Diff: 0.4
# Epoch: 5	s: {'x2': 1.6, 'x4': 0.8, 'x1': 0.6, 'x3': 0.9}    	t: 0.957	Accepted: False	Diff: -0.4
# Epoch: 6	s: {'x2': 1.6, 'x4': 0.9, 'x1': 0.6, 'x3': 1.0}    	t: 0.957	Accepted: True	Diff: 0.1
# Epoch: 7	s: {'x2': 1.7, 'x4': 0.9, 'x1': 0.6, 'x3': 1.0}    	t: 0.957	Accepted: True	Diff: 0.5
# Epoch: 8	s: {'x2': 1.7, 'x4': 1.0, 'x1': 0.6, 'x3': 1.0}    	t: 0.957	Accepted: True	Diff: 0.1
# Epoch: 9	s: {'x2': 1.7, 'x4': 1.0, 'x1': 0.5, 'x3': 1.0}    	t: 0.957	Accepted: False	Diff: -0.3
# Epoch: 10	s: {'x2': 1.8, 'x4': 1.0, 'x1': 0.6, 'x3': 1.0}    	t: 0.957	Accepted: True	Diff: 0.5
# --------------------------------------------------------------------------------------------
# s_8: {'x2': 1.8, 'x4': 1.0, 'x1': 0.6, 'x3': 1.0}
# Epoch: 1	s: {'x2': 1.8, 'x4': 1.1, 'x1': 0.6, 'x3': 1.0}    	t: 0.861	Accepted: True	Diff: 0.1
# Epoch: 2	s: {'x2': 1.9, 'x4': 1.1, 'x1': 0.6, 'x3': 1.0}    	t: 0.861	Accepted: True	Diff: 0.5
# Epoch: 3	s: {'x2': 1.8, 'x4': 1.1, 'x1': 0.6, 'x3': 1.0}    	t: 0.861	Accepted: True	Diff: -0.5
# Epoch: 4	s: {'x2': 1.8, 'x4': 1.2, 'x1': 0.6, 'x3': 1.0}    	t: 0.861	Accepted: True	Diff: 0.1
# Epoch: 5	s: {'x2': 1.9, 'x4': 1.2, 'x1': 0.6, 'x3': 1.0}    	t: 0.861	Accepted: True	Diff: 0.5
# Epoch: 6	s: {'x2': 1.8, 'x4': 1.2, 'x1': 0.6, 'x3': 1.0}    	t: 0.861	Accepted: False	Diff: -0.5
# Epoch: 7	s: {'x2': 1.9, 'x4': 1.1, 'x1': 0.6, 'x3': 1.0}    	t: 0.861	Accepted: True	Diff: -0.1
# Epoch: 8	s: {'x2': 1.9, 'x4': 1.2, 'x1': 0.6, 'x3': 1.0}    	t: 0.861	Accepted: True	Diff: 0.1
# Epoch: 9	s: {'x2': 1.9, 'x4': 1.2, 'x1': 0.7, 'x3': 1.0}    	t: 0.861	Accepted: True	Diff: 0.3
# Epoch: 10	s: {'x2': 1.9, 'x4': 1.2, 'x1': 0.6, 'x3': 1.0}    	t: 0.861	Accepted: False	Diff: -0.3
# (red constraint fails)
#
# Stats:
# x1 not -ve constraint: 0 <= 0.6
# x2 not -ve constraint: 0 <= 1.8000000000000005
# x3 not -ve constraint: 0 <= 0.9999999999999999
# x4 not -ve constraint: 0 <= 0.9999999999999999
# green constraint: 6.2 <= 10
# red constraint: 6.0 <= 6
# blue constraint: 3.6 <= 10
# yellow constraint: 7.8 <= 18
# brown constraint: 4.0 <= 8
# purple constraint: 6.0 <= 12
#
# Profit: 15.8
# Solution: [0.6, 1.8, 1.0, 1.0]
