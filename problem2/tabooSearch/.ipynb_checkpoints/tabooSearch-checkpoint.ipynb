# %%
import math
import sys

# Allows me to import my modules
sys.path.extend(["../../modules", "../"])

# Imports the python definition of f(x) for problem 1.

from problem import f, constraints, check_all_constraints, print_all_constraints

# %%
###### Taboo search stuff
'''
        f                  :   The problem function which is being investigated by the metaheuristic.
        s_0                :   The starting point.
        stopping_cond      :   The function which returns whether to stop the algorithm.
        stopping_args      :   The constant arguments passed to the neighbourhood function.
        taboo_memory       :   The maximum number of taboo values that can be stored.
        neighbourhood_func :   The function which returns the neighbourhood of values about a value.
        neighbourhood_args :   The constant arguments passed to the neighbourhood function.
'''

class TS_defaults:
    def __init__(self, s_0, stopping_cond, stop_args, taboo_memory, neighbourhood_func, neighbourhood_args):
        self.s_0 = s_0
        self.stopping_cond = stopping_cond
        self.stop_args = stop_args
        self.taboo_memory = taboo_memory
        self.neighbourhood_func = neighbourhood_func
        self.neighbourhood_args = neighbourhood_args

def taboo_search(f, is_maximisation, constraints, DEFAULTS, s_0 = None, stopping_cond = None, stop_args = None, taboo_memory = None, neighbourhood_func = None, neighbourhood_args = None, print_workings=False):
    # Default parameters
    s_0 = DEFAULTS.s_0 if s_0 is None else s_0
    stopping_cond = DEFAULTS.stopping_cond if stopping_cond is None else stopping_cond
    stop_args = DEFAULTS.stop_args if stop_args is None else stop_args
    taboo_memory = DEFAULTS.taboo_memory if taboo_memory is None else taboo_memory
    neighbourhood_func = DEFAULTS.neighbourhood_func if neighbourhood_func is None else neighbourhood_func
    neighbourhood_args = DEFAULTS.neighbourhood_args if neighbourhood_args is None else neighbourhood_args
    
    # Initial values of local variables
    taboo_list = [s_0]
    s = {k: v for k, v in s_0.items()}
    i = 1
    
    # Keeps track of where the algorithm has been (without affecting the answer)
    history = [s]
    viable_neighbours = None
    while True:
        neighbourhood = neighbourhood_func(s, **neighbourhood_args)
        neighbourhood = list(filter(lambda item: item not in taboo_list, neighbourhood))
        neighbourhood = list(filter(lambda item: check_all_constraints(item, constraints, print_workings), neighbourhood))
        viable_neighbours = len(neighbourhood)
        if (viable_neighbours > 0):
            neighbourhood.sort(key=lambda item: f(item), reverse=is_maximisation)
            best = neighbourhood[0]
            if ((is_maximisation and f(best) > f(s)) or (not is_maximisation and f(best) < f(s))):
                s = {k: v for k, v in best.items()}
                history.append(best)
            if (len(taboo_list) == taboo_memory):
                taboo_list.pop(0)
            taboo_list.append(best)
        if (print_workings == True):
            print("Iteration: {},\tCurrent solution: {},\tTaboo list: {}".format(i, s, taboo_list))
        if (stopping_cond(i, s, viable_neighbours, **stop_args)):
            break
        i += 1
    # Add final solution
    if (i == 1):
        return ([], False)
    history.append(s)
    return (history, s)

# %%
s_0 = {"x1": 0, "x2": 0, "x3": 0, "x4": 0}

def stopping_cond(i, s, viable_neighbours, max_i):
    return (i != 0 and (max_i < i or (viable_neighbours == 0)))

stopping_args = {"max_i": 300}
taboo_memory = 8

def neighbourhood_func(s_0, step_size):
    neighbourhood = []
    keys = s_0.keys()
    for i in range(len(keys)*2):
        sign = 1 if i < 4 else -1
        key = list(keys)[i % 4]
        neighbour = {k: v for k, v in s_0.items()}
        neighbour[key] += sign*step_size
        neighbourhood.append(neighbour)
    return neighbourhood

neighbourhood_args = {"step_size": 0.1}

DEFAULTS = TS_defaults(s_0 = s_0, stopping_cond = stopping_cond, stop_args = stopping_args, taboo_memory = taboo_memory, neighbourhood_func = neighbourhood_func, neighbourhood_args = neighbourhood_args)

# %%
results = taboo_search(f, True, constraints, DEFAULTS, print_workings=True)
# Out:
# (x3 not -ve constraint fails)
# (x1 not -ve constraint fails)
# (x4 not -ve constraint fails)
# (x2 not -ve constraint fails)
# Iteration: 1,	Current solution: {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.1},	Taboo list: [{'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.1}]
# (x3 not -ve constraint fails)
# (x1 not -ve constraint fails)
# (x4 not -ve constraint fails)
# Iteration: 2,	Current solution: {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.2},	Taboo list: [{'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.1}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.2}]
# (x3 not -ve constraint fails)
# (x1 not -ve constraint fails)
# (x4 not -ve constraint fails)
# Iteration: 3,	Current solution: {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.30000000000000004},	Taboo list: [{'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.1}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.2}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.30000000000000004}]
# (x3 not -ve constraint fails)
# (x1 not -ve constraint fails)
# (x4 not -ve constraint fails)
# Iteration: 4,	Current solution: {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.4},	Taboo list: [{'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.1}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.2}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.30000000000000004}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.4}]
# (x3 not -ve constraint fails)
# (x1 not -ve constraint fails)
# (x4 not -ve constraint fails)
# Iteration: 5,	Current solution: {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.5},	Taboo list: [{'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.1}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.2}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.30000000000000004}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.4}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.5}]
# (x3 not -ve constraint fails)
# (x1 not -ve constraint fails)
# (x4 not -ve constraint fails)
# Iteration: 6,	Current solution: {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.6},	Taboo list: [{'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.1}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.2}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.30000000000000004}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.4}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.5}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.6}]
# (x3 not -ve constraint fails)
# (x1 not -ve constraint fails)
# (x4 not -ve constraint fails)
# Iteration: 7,	Current solution: {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.7},	Taboo list: [{'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.1}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.2}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.30000000000000004}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.4}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.5}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.6}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.7}]
# (x3 not -ve constraint fails)
# (x1 not -ve constraint fails)
# (x4 not -ve constraint fails)
# Iteration: 8,	Current solution: {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.7999999999999999},	Taboo list: [{'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.1}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.2}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.30000000000000004}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.4}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.5}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.6}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.7}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.7999999999999999}]
# (x3 not -ve constraint fails)
# (x1 not -ve constraint fails)
# (x4 not -ve constraint fails)
# Iteration: 9,	Current solution: {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.8999999999999999},	Taboo list: [{'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.2}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.30000000000000004}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.4}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.5}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.6}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.7}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.7999999999999999}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.8999999999999999}]
# (x3 not -ve constraint fails)
# (x1 not -ve constraint fails)
# (x4 not -ve constraint fails)
# Iteration: 10,	Current solution: {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.9999999999999999},	Taboo list: [{'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.30000000000000004}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.4}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.5}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.6}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.7}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.7999999999999999}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.8999999999999999}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.9999999999999999}]
# (x3 not -ve constraint fails)
# (x1 not -ve constraint fails)
# (x4 not -ve constraint fails)
# Iteration: 11,	Current solution: {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.0999999999999999},	Taboo list: [{'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.4}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.5}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.6}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.7}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.7999999999999999}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.8999999999999999}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.9999999999999999}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.0999999999999999}]
# (x3 not -ve constraint fails)
# (x1 not -ve constraint fails)
# (x4 not -ve constraint fails)
# Iteration: 12,	Current solution: {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.2},	Taboo list: [{'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.5}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.6}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.7}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.7999999999999999}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.8999999999999999}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.9999999999999999}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.0999999999999999}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.2}]
# (x3 not -ve constraint fails)
# (x1 not -ve constraint fails)
# (x4 not -ve constraint fails)
# Iteration: 13,	Current solution: {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.3},	Taboo list: [{'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.6}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.7}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.7999999999999999}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.8999999999999999}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.9999999999999999}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.0999999999999999}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.2}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.3}]
# (x3 not -ve constraint fails)
# (x1 not -ve constraint fails)
# (x4 not -ve constraint fails)
# Iteration: 14,	Current solution: {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.4000000000000001},	Taboo list: [{'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.7}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.7999999999999999}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.8999999999999999}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.9999999999999999}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.0999999999999999}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.2}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.3}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.4000000000000001}]
# (x3 not -ve constraint fails)
# (x1 not -ve constraint fails)
# (x4 not -ve constraint fails)
# Iteration: 15,	Current solution: {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.5000000000000002},	Taboo list: [{'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.7999999999999999}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.8999999999999999}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.9999999999999999}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.0999999999999999}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.2}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.3}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.4000000000000001}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.5000000000000002}]
# (x3 not -ve constraint fails)
# (x1 not -ve constraint fails)
# (x4 not -ve constraint fails)
# Iteration: 16,	Current solution: {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.6000000000000003},	Taboo list: [{'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.8999999999999999}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.9999999999999999}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.0999999999999999}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.2}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.3}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.4000000000000001}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.5000000000000002}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.6000000000000003}]
# (x3 not -ve constraint fails)
# (x1 not -ve constraint fails)
# (x4 not -ve constraint fails)
# Iteration: 17,	Current solution: {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.7000000000000004},	Taboo list: [{'x3': 0, 'x1': 0, 'x4': 0, 'x2': 0.9999999999999999}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.0999999999999999}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.2}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.3}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.4000000000000001}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.5000000000000002}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.6000000000000003}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.7000000000000004}]
# (x3 not -ve constraint fails)
# (x1 not -ve constraint fails)
# (x4 not -ve constraint fails)
# Iteration: 18,	Current solution: {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.8000000000000005},	Taboo list: [{'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.0999999999999999}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.2}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.3}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.4000000000000001}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.5000000000000002}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.6000000000000003}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.7000000000000004}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.8000000000000005}]
# (x3 not -ve constraint fails)
# (x1 not -ve constraint fails)
# (x4 not -ve constraint fails)
# Iteration: 19,	Current solution: {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.9000000000000006},	Taboo list: [{'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.2}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.3}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.4000000000000001}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.5000000000000002}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.6000000000000003}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.7000000000000004}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.8000000000000005}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.9000000000000006}]
# (x3 not -ve constraint fails)
# (x1 not -ve constraint fails)
# (x4 not -ve constraint fails)
# Iteration: 20,	Current solution: {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 2.0000000000000004},	Taboo list: [{'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.3}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.4000000000000001}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.5000000000000002}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.6000000000000003}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.7000000000000004}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.8000000000000005}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.9000000000000006}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 2.0000000000000004}]
# (x3 not -ve constraint fails)
# (x1 not -ve constraint fails)
# (x4 not -ve constraint fails)
# Iteration: 21,	Current solution: {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 2.1000000000000005},	Taboo list: [{'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.4000000000000001}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.5000000000000002}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.6000000000000003}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.7000000000000004}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.8000000000000005}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.9000000000000006}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 2.0000000000000004}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 2.1000000000000005}]
# (x3 not -ve constraint fails)
# (x1 not -ve constraint fails)
# (x4 not -ve constraint fails)
# Iteration: 22,	Current solution: {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 2.2000000000000006},	Taboo list: [{'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.5000000000000002}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.6000000000000003}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.7000000000000004}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.8000000000000005}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.9000000000000006}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 2.0000000000000004}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 2.1000000000000005}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 2.2000000000000006}]
# (x3 not -ve constraint fails)
# (x1 not -ve constraint fails)
# (x4 not -ve constraint fails)
# Iteration: 23,	Current solution: {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 2.3000000000000007},	Taboo list: [{'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.6000000000000003}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.7000000000000004}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.8000000000000005}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.9000000000000006}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 2.0000000000000004}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 2.1000000000000005}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 2.2000000000000006}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 2.3000000000000007}]
# (x3 not -ve constraint fails)
# (x1 not -ve constraint fails)
# (x4 not -ve constraint fails)
# Iteration: 24,	Current solution: {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 2.400000000000001},	Taboo list: [{'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.7000000000000004}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.8000000000000005}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.9000000000000006}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 2.0000000000000004}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 2.1000000000000005}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 2.2000000000000006}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 2.3000000000000007}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 2.400000000000001}]
# (x3 not -ve constraint fails)
# (x1 not -ve constraint fails)
# (x4 not -ve constraint fails)
# Iteration: 25,	Current solution: {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 2.500000000000001},	Taboo list: [{'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.8000000000000005}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 1.9000000000000006}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 2.0000000000000004}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 2.1000000000000005}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 2.2000000000000006}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 2.3000000000000007}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 2.400000000000001}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 2
	Taboo list: [{'x3': 0, 'x1': 0, 'x4': 0, 'x2': 4.000000000000002}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 4.100000000000001}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 4.200000000000001}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 4.300000000000001}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 4.4}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 4.5}, {'x3': 0.1, 'x1': 0, 'x4': 0, 'x2': 4.5}, {'x3': 0.2, 'x1': 0, 'x4': 0, 'x2': 4.5}]
# (yellow constraint fails)
# (yellow constraint fails)
# (x1 not -ve constraint fails)
# (x4 not -ve constraint fails)
# Iteration: 48,	Current solution: {'x3': 0.30000000000000004, 'x1': 0, 'x4': 0, 'x2': 4.5},	Taboo list: [{'x3': 0, 'x1': 0, 'x4': 0, 'x2': 4.100000000000001}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 4.200000000000001}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 4.300000000000001}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 4.4}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 4.5}, {'x3': 0.1, 'x1': 0, 'x4': 0, 'x2': 4.5}, {'x3': 0.2, 'x1': 0, 'x4': 0, 'x2': 4.5}, {'x3': 0.30000000000000004, 'x1': 0, 'x4': 0, 'x2': 4.5}]
# (yellow constraint fails)
# (yellow constraint fails)
# (x1 not -ve constraint fails)
# (x4 not -ve constraint fails)
# Iteration: 49,	Current solution: {'x3': 0.4, 'x1': 0, 'x4': 0, 'x2': 4.5},	Taboo list: [{'x3': 0, 'x1': 0, 'x4': 0, 'x2': 4.200000000000001}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 4.300000000000001}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 4.4}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 4.5}, {'x3': 0.1, 'x1': 0, 'x4': 0, 'x2': 4.5}, {'x3': 0.2, 'x1': 0, 'x4': 0, 'x2': 4.5}, {'x3': 0.30000000000000004, 'x1': 0, 'x4': 0, 'x2': 4.5}, {'x3': 0.4, 'x1': 0, 'x4': 0, 'x2': 4.5}]
# (yellow constraint fails)
# (yellow constraint fails)
# (x1 not -ve constraint fails)
# (x4 not -ve constraint fails)
# Iteration: 50,	Current solution: {'x3': 0.5, 'x1': 0, 'x4': 0, 'x2': 4.5},	Taboo list: [{'x3': 0, 'x1': 0, 'x4': 0, 'x2': 4.300000000000001}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 4.4}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 4.5}, {'x3': 0.1, 'x1': 0, 'x4': 0, 'x2': 4.5}, {'x3': 0.2, 'x1': 0, 'x4': 0, 'x2': 4.5}, {'x3': 0.30000000000000004, 'x1': 0, 'x4': 0, 'x2': 4.5}, {'x3': 0.4, 'x1': 0, 'x4': 0, 'x2': 4.5}, {'x3': 0.5, 'x1': 0, 'x4': 0, 'x2': 4.5}]
# (yellow constraint fails)
# (yellow constraint fails)
# (x1 not -ve constraint fails)
# (x4 not -ve constraint fails)
# Iteration: 51,	Current solution: {'x3': 0.6, 'x1': 0, 'x4': 0, 'x2': 4.5},	Taboo list: [{'x3': 0, 'x1': 0, 'x4': 0, 'x2': 4.4}, {'x3': 0, 'x1': 0, 'x4': 0, 'x2': 4.5}, {'x3': 0.1, 'x1': 0, 'x4': 0, 'x2': 4.5}, {'x3': 0.2, 'x1': 0, 'x4': 0, 'x2': 4.5}, {'x3': 0.30000000000000004, 'x1': 0, 'x4': 0, 'x2': 4.5}, {'x3': 0.4, 'x1': 0, 'x4': 0, 'x2': 4.5}, {'x3': 0.5, 'x1': 0, 'x4': 0, 'x2': 4.5}, {'x3': 0.6, 'x1': 0, 'x4': 0, 'x2': 4.5}]
# (yellow constraint fails)
# (yellow constraint fails)
# (x1 not -ve constraint fails)
# (x4 not -ve constraint fails)
# Iteration: 52,	Current solution: {'x3': 0.7, 'x1': 0, 'x4': 0, 'x2': 4.5},	Taboo list: [{'x3': 0, 'x1': 0, 'x4': 0, 'x2': 4.5}, {'x3': 0.1, 'x1': 0, 'x4': 0, 'x2': 4.5}, {'x3': 0.2, 'x1': 0, 'x4': 0, 'x2': 4.5}, {'x3': 0.30000000000000004, 'x1': 0, 'x4': 0, 'x2': 4.5}, {'x3': 0.4, 'x1': 0, 'x4': 0, 'x2': 4.5}, {'x3': 0.5, 'x1': 0, 'x4': 0, 'x2': 4.5}, {'x3': 0.6, 'x1': 0, 'x4': 0, 'x2': 4.5}, {'x3': 0.7, 'x1': 0, 'x4': 0, 'x2': 4.5}]
# (red constraint fails)
# (red constraint fails)
# (yellow constraint fails)
# (x1 not -ve constraint fails)
# (x4 not -ve constraint fails)
# Iteration: 53,	Current solution: {'x3': 0.7, 'x1': 0, 'x4': 0.1, 'x2': 4.5},	Taboo list: [{'x3': 0.1, 'x1': 0, 'x4': 0, 'x2': 4.5}, {'x3': 0.2, 'x1': 0, 'x4': 0, 'x2': 4.5}, {'x3': 0.30000000000000004, 'x1': 0, 'x4': 0, 'x2': 4.5}, {'x3': 0.4, 'x1': 0, 'x4': 0, 'x2': 4.5}, {'x3': 0.5, 'x1': 0, 'x4': 0, 'x2': 4.5}, {'x3': 0.6, 'x1': 0, 'x4': 0, 'x2': 4.5}, {'x3': 0.7, 'x1': 0, 'x4': 0, 'x2': 4.5}, {'x3': 0.7, 'x1': 0, 'x4': 0.1, 'x2': 4.5}]
# (red constraint fails)
# (red constraint fails)
# (red constraint fails)
# (red constraint fails)
# (x1 not -ve constraint fails)
# Iteration: 54,	Current solution: {'x3': 0.7, 'x1': 0, 'x4': 0.1, 'x2': 4.5},	Taboo list: [{'x3': 0.2, 'x1': 0, 'x4': 0, 'x2': 4.5}, {'x3': 0.30000000000000004, 'x1': 0, 'x4': 0, 'x2': 4.5}, {'x3': 0.4, 'x1': 0, 'x4': 0, 'x2': 4.5}, {'x3': 0.5, 'x1': 0, 'x4': 0, 'x2': 4.5}, {'x3': 0.6, 'x1': 0, 'x4': 0, 'x2': 4.5}, {'x3': 0.7, 'x1': 0, 'x4': 0, 'x2': 4.5}, {'x3': 0.7, 'x1': 0, 'x4': 0.1, 'x2': 4.5}, {'x3': 0.6, 'x1': 0, 'x4': 0.1, 'x2': 4.5}]
# (red constraint fails)
# (red constraint fails)
# (red constraint fails)
# (red constraint fails)
# (x1 not -ve constraint fails)
# Iteration: 55,	Current solution: {'x3': 0.7, 'x1': 0, 'x4': 0.1, 'x2': 4.5},	Taboo list: [{'x3': 0.30000000000000004, 'x1': 0, 'x4': 0, 'x2': 4.5}, {'x3': 0.4, 'x1': 0, 'x4': 0, 'x2': 4.5}, {'x3': 0.5, 'x1': 0, 'x4': 0, 'x2': 4.5}, {'x3': 0.6, 'x1': 0, 'x4': 0, 'x2': 4.5}, {'x3': 0.7, 'x1': 0, 'x4': 0, 'x2': 4.5}, {'x3': 0.7, 'x1': 0, 'x4': 0.1, 'x2': 4.5}, {'x3': 0.6, 'x1': 0, 'x4': 0.1, 'x2': 4.5}, {'x3': 0.7, 'x1': 0, 'x4': 0.1, 'x2': 4.4}]
# (red constraint fails)
# (red constraint fails)
# (red constraint fails)
# (red constraint fails)
# (x1 not -ve constraint fails)
# Iteration: 56,	Current solution: {'x3': 0.7, 'x1': 0, 'x4': 0.1, 'x2': 4.5},	Taboo list: [{'x3': 0.30000000000000004, 'x1': 0, 'x4': 0, 'x2': 4.5}, {'x3': 0.4, 'x1': 0, 'x4': 0, 'x2': 4.5}, {'x3': 0.5, 'x1': 0, 'x4': 0, 'x2': 4.5}, {'x3': 0.6, 'x1': 0, 'x4': 0, 'x2': 4.5}, {'x3': 0.7, 'x1': 0, 'x4': 0, 'x2': 4.5}, {'x3': 0.7, 'x1': 0, 'x4': 0.1, 'x2': 4.5}, {'x3': 0.6, 'x1': 0, 'x4': 0.1, 'x2': 4.5}, {'x3': 0.7, 'x1': 0, 'x4': 0.1, 'x2': 4.4}]

# %%
print_all_constraints(results[1], constraints)
print("Profit: ", f(results[1]))
# Out:
# x1 not -ve constraint: 0 <= 0
# x2 not -ve constraint: 0 <= 4.5
# x3 not -ve constraint: 0 <= 0.7
# x4 not -ve constraint: 0 <= 0.1
# green constraint: 9.8 <= 10
# red constraint: 6.0 <= 6
# blue constraint: 4.5 <= 10
# yellow constraint: 18.0 <= 18
# brown constraint: 1.0 <= 8
# purple constraint: 2.4 <= 12
# Profit:  25.400000000000002

# %%
# Imports my plotting module
import batch_plotting as batch_plt

# Imports my spiral coordinate generating module
from utilities import n_dim_spiral

# %%
# Batch testing start position
starting_point_results = []
end_point = []
spiral = n_dim_spiral({"x1": 0, "x2": 0, "x3": 0, "x4": 0}, 1000, 0.1)
for j in range(len(spiral)):
    ps = spiral[j]
    result = taboo_search(f, True, constraints, DEFAULTS, s_0 = ps)
    end_point.append(result[1])
    starting_point_results.append({"x": j, "y": f(result[1]) if result[1] is not False else False})

# %%
batch_plt.plot_2d_batch_accuracy("profit: f(s_n)", "starting point: s_0", False, starting_point_results)

# %%
end_point[0:10]
# Out:
# [False, False, False, False, False, False, False, False, False, False]

# %%
print_all_constraints({'x1': 1.0999999999999999,
  'x2': 0.5,
  'x3': 1.0999999999999999,
  'x4': 1.0999999999999999}, constraints)
# Out:
# x1 not -ve constraint: 0 <= 1.0999999999999999
# x2 not -ve constraint: 0 <= 0.5
# x3 not -ve constraint: 0 <= 1.0999999999999999
# x4 not -ve constraint: 0 <= 1.0999999999999999
# green constraint: 4.3 <= 10
# red constraint: 6.0 <= 6
# blue constraint: 3.8 <= 10
# yellow constraint: 3.1 <= 18
# brown constraint: 4.4 <= 8
# purple constraint: 6.6 <= 12

# %%
step_size_results = []
end_point = []

# Batch testing step size
for s in range(20):
    step_size = (s+1)/20
    result = taboo_search(f, True, constraints, DEFAULTS, neighbourhood_args={"step_size": step_size})
    end_point.append(result[1])
    step_size_results.append({"x": step_size, "y": f(result[1]) if result[1] is not False else False})

# %%
batch_plt.plot_2d_batch_accuracy("profit: f(s_n)", "step size", False, step_size_results)

# %%
print_all_constraints(end_point[0], constraints)
print("Profit: ", f(end_point[0]))
# Out:
# x1 not -ve constraint: 0 <= 0
# x2 not -ve constraint: 0 <= 4.499999999999992
# x3 not -ve constraint: 0 <= 0.7500000000000001
# x4 not -ve constraint: 0 <= 0
# green constraint: 9.75 <= 10
# red constraint: 6.0 <= 6
# blue constraint: 4.5 <= 10
# yellow constraint: 18.0 <= 18
# brown constraint: 0.75 <= 8
# purple constraint: 2.25 <= 12
# Profit:  25.49999999999996
